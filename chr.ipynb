# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import re
from bs4 import BeautifulSoup

# 웹드라이버 초기 설정
options = Options()
options.add_experimental_option("detach", True)
driver = webdriver.Chrome(executable_path='C:\\Users\\USER\\Downloads\\chromedriver_win32\\chromedriver.exe', options=options)

# 로그인 페이지 열기
login_url = "http://www.sdulife.com/99_Etc/DupLogin.asp?Referrer=stud.sdulife.com/Frameset/Main.asp"
driver.get(login_url)
time.sleep(1)
input("공인인증서, PC등록 완료되면 엔터키")
# Out:
# ''

# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11#'
payload = {
'method: searchReductionCapital',
'forward: searchreductioncapital',
'selMonth: 06',
'searchMenu: 06',
'nowYear: 2023',
'nowMonth: 11',
'searchCorpName: 회사명/코드',
'selYear: 2023',
'showMonth: 6',
'periodType: M',
'selDate: 2023-06-01', 
'submitFlagYn: N'
}

data = rq.post(url, data=payload)
html = BeautifulSoup(data.content, 'html.parser')

print(html)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#    1000         try:
# -> 1001             self.sock.sendall(data)
#    1002         except TypeError:
#
# c:\ProgramData\Anaconda3\lib\ssl.py in sendall(self, data, flags)
#    1201             count = 0
# -> 1202             with memoryview(data) as view, view.cast("B") as byte_view:
#    1203                 amount = len(byte_view)
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10380\936085360.py in <module>
#      19 }
#      20
# ---> 21 data = rq.post(url, data=payload)
#      22 html = BeautifulSoup(data.content, 'html.parser')
#      23
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     396                 conn.request_chunked(method, url, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#     400         # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#
# c:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     237         if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#     241     def request_chunked(self, method, url, body=None, headers=None):
#
# c:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1283                 encode_chunked=False):
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#    1287     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1329             # default charset of iso-8859-1.
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#    1333     def getresponse(self):
#
# c:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1278         else:
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#    1282     def request(self, method, url, body=None, headers={}, *,
#
# c:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1077                     chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1078                         + b'\r\n'
# -> 1079                 self.send(chunk)
#    1080
#    1081             if encode_chunked and self._http_vsn == 11:
#
# c:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#    1003             if isinstance(data, collections.abc.Iterable):
#    1004                 for d in data:
# -> 1005                     self.sock.sendall(d)
#    1006             else:
#    1007                 raise TypeError("data should be a bytes-like object "
#
# c:\ProgramData\Anaconda3\lib\ssl.py in sendall(self, data, flags)
#    1200                     self.__class__)
#    1201             count = 0
# -> 1202             with memoryview(data) as view, view.cast("B") as byte_view:
#    1203                 amount = len(byte_view)
#    1204                 while count < amount:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'

# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11#'
for i in range(1, 13):
    payload = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': f'0{i}',
        # 'searchMenu': '06',
        # 'nowYear': '2023',
        # 'nowMonth': '11',
        'searchCorpName': '회사명/코드',
        'selYear': '2023',
        'showMonth': f'{i}',
        'periodType': 'M',
        'selDate': f'2023-0{i}-01', 
        'submitFlagYn': 'N'
    }

    data = rq.post(url, data=payload)
    html = BeautifulSoup(data.content, 'html.parser')

    print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="kr" http-equiv="content-language"/>
#   <meta content="text/css" http-equiv="content-style-type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="no" http-equiv="imagetoolbar"/>
#   <meta content="(c)2012" name="copyright"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="description"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="keywords"/>
#   <title>
#    대한민국 대표 기업공시채널 KIND
#   </title>
#   <link href="../js/jquery/themes-base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/default_new.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/common.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/popup.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
#   <script src="../js/trans.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="../js/common.js" type="text/javascript">
#   </script>
#   <script src="../js/common-pop.js?version=20220624" type="text/javascript">
#   </script>
#   <script src="../js/common-ajax.js" type="text/javascript">
#   </script>
#   <script src="../js/JCommon.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="pop">
#   <header class="popup">
#    <h1 class="ttl type-99" id="title">
#     증시일정
#    </h1>
#   </header>
#   <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
#    <input id="method" name="method" type="hidden"/>
#    <input id="forward" name="forward" type="hidden"/>
#    <input id="searchCodeType" name="searchCodeType" type="hidden"/>
#    <!--number:법인코드 char:법인명-->
#    <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden"/>
#    <!--법인코드-->
#    <input id="menuIndex" name="menuIndex" type="hidden"/>
#    <!--검색할 페이지-->
#    <input id="selMonth" name="selMonth" type="hidden"/>
#    <!--월-->
#    <input id="selDay" name="selDay" type="hidden"/>
#    <!--일자-->
#    <input id="enterFlag" name="enterFlag" type="hidden"/>
#    <input id="searchMenu" name="searchMenu" type="hidden" value="01"/>
#    <input id="nowYear" name="nowYear" type="hidden" value="2023"/>
#    <input id="nowMonth" name="nowMonth" type="hidden" value="11"/>
#    <!-- 리스트검색 -->
#    <section class="contents popup">
#     <section class="roundbox type-99">
#      <div class="form-search type-99">
#       <table summary="검색">
#        <caption>
#         증시일정
#        </caption>
#        <colgroup>
#         <col width="50"/>
#         <col width="200"/>
#         <col width="90"/>
#         <col width="*"/>
#        </colgroup>
#        <tbody>
#         <tr class="first">
#          <th scope="row">
#           <label for="name">
#            회사명
#           </label>
#          </th>
#          <td>
#           <input class="middle" id="searchCorpName" name="searchCorpName" onclick="fnTextInit(); return false;" type="text"/>
#           <a href="#searchCorp" onclick="findCompanyName();return false;" title="회사명찾기">
#            <img alt="회사명찾기" class="vtop" id="searchCorp" src="../../images/common/btn_zoom.gif"/>
#           </a>
#          </td>
#          <td>
#           <select class="select" id="selYear" name="selYear" onchange="fnYearChange()">
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option selected="selected" value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#            <option value="2025">
#             2025
#            </option>
#           </select>
#           년
#           <select class="select" id="showMonth" name="showMonth" style="display:none">
#            <option value="1">
#             1
#            </option>
#            <option value="2">
#             2
#            </option>
#            <option value="3">
#             3
#            </option>
#            <option value="4">
#             4
#            </option>
#            <option value="5">
#             5
#            </option>
#            <option value="6">
#             6
#            </option>
#            <option value="7">
#             7
#            </option>
#            <option value="8">
#             8
#            </option>
#            <option value="9">
#             9
#            </option>
#            <option value="10">
#             10
#            </option>
#            <option selected="selected" value="11">
#             11
#            </option>
#            <option value="12">
#             12
#            </option>
#           </select>
#          </td>
#          <td>
#           <ul class="btn-set months">
#            <li>
#             <a class="ord-00" href="#" id="january" onclick="fnSwapImage('1', 'click')" title="1월">
#              <span>
#               1월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-01" href="#" id="february" onclick="fnSwapImage('2', 'click')" title="2월">
#              <span>
#               2월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-02" href="#" id="march" onclick="fnSwapImage('3', 'click')" title="3월">
#              <span>
#               3월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-03" href="#" id="april" onclick="fnSwapImage('4', 'click')" title="4월">
#              <span>
#               4월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-04" href="#" id="may" onclick="fnSwapImage('5', 'click')" title="5월">
#              <span>
#               5월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-05" href="#" id="june" onclick="fnSwapImage('6', 'click')" title="6월">
#              <span>
#               6월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-06" href="#" id="july" onclick="fnSwapImage('7', 'click')" title="7월">
#              <span>
#               7월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-07" href="#" id="august" onclick="fnSwapImage('8', 'click')" title="8월">
#              <span>
#               8월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-08" href="#" id="september" onclick="fnSwapImage('9', 'click')" title="9월">
#              <span>
#               9월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-09" href="#" id="october" onclick="fnSwapImage('10', 'click')" title="10월">
#              <span>
#               10월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-10" href="#" id="november" onclick="fnSwapImage('11', 'click')" title="11월">
#              <span>
#               11월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-11" href="#" id="december" onclick="fnSwapImage('12', 'click')" title="12월">
#              <span>
#               12월
#              </span>
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#      <img alt="" class="tl" src="../images/common/rbox-type-99-tl.png"/>
#      <img alt="" class="bl" src="../images/common/rbox-type-99-bl.png"/>
#      <img alt="" class="tr" src="../images/common/rbox-type-99-tr.png"/>
#      <img alt="" class="br" src="../images/common/rbox-type-99-br.png"/>
#      <div class="tm">
#      </div>
#      <div class="lm">
#      </div>
#      <div class="bm">
#      </div>
#      <div class="rm">
#      </div>
#     </section>
#     <nav class="tabgroup type-97 mt10">
#      <ul>
#       <li id="A">
#        <a href="#" onclick="fnSearchInit('01'); fnClassActive('01'); return false;" title="종합">
#         <span>
#          종합
#         </span>
#        </a>
#       </li>
#       <li id="B">
#        |
#        <a href="#" onclick="fnSearchInit('02'); fnClassActive('02'); return false;" title="유상종자">
#         <span>
#          유상증자
#         </span>
#        </a>
#       </li>
#       <li id="C">
#        |
#        <a href="#" onclick="fnSearchInit('03'); fnClassActive('03'); return false;" title="무상종자">
#         <span>
#          무상증자
#         </span>
#        </a>
#       </li>
#       <li id="D">
#        |
#        <a href="#" onclick="fnSearchInit('04'); fnClassActive('04'); return false;" title="액면변경">
#         <span>
#          액면변경
#         </span>
#        </a>
#       </li>
#       <li id="E">
#        |
#        <a href="#" onclick="fnSearchInit('05'); fnClassActive('05'); return false;" title="주식배당">
#         <span>
#          주식배당
#         </span>
#        </a>
#       </li>
#       <li id="F">
#        |
#        <a href="#" onclick="fnSearchInit('06'); fnClassActive('06'); return false;" title="감자">
#         <span>
#          감자
#         </span>
#        </a>
#       </li>
#       <li id="G">
#        |
#        <a href="#" onclick="fnSearchInit('07'); fnClassActive('07'); return false;" title="분할/합병">
#         <span>
#          분할/합병
#         </span>
#        </a>
#       </li>
#       <li id="H">
#        |
#        <a href="#" onclick="fnSearchInit('08'); fnClassActive('08'); return false;" title="상호변경">
#         <span>
#          상호변경
#         </span>
#        </a>
#       </li>
#       <li id="I">
#        |
#        <a href="#" onclick="fnSearchInit('09'); fnClassActive('09'); return false;" title="결산실적공시 예정">
#         <span>
#          결산실적공시 예정
#         </span>
#        </a>
#       </li>
#       <li id="J">
#        |
#        <a href="#" onclick="fnSearchInit('10'); fnClassActive('10'); return false;" title="주주총회">
#         <span>
#          주주총회
#         </span>
#        </a>
#       </li>
#       <li id="K">
#        |
#        <a href="#" onclick="fnSearchInit('11'); fnClassActive('11'); return false;" title="감사보고서 제출 현황">
#         <span>
#          감사보고서 제출 현황
#         </span>
#        </a>
#       </li>
#       <li id="L">
#        |
#        <a href="#" onclick="fnSearchInit('12'); fnClassActive('12'); return false;" title="불성실공시법인지정">
#         <span>
#          불성실공시법인지정
#         </span>
#        </a>
#       </li>
#       <li id="M">
#        |
#        <a href="#" onclick="fnSearchInit('13'); fnClassActive('13'); return false;" title="트레이딩캘린더">
#         <span>
#          트레이딩캘린더
#         </span>
#        </a>
#       </li>
#      </ul>
#      <div class="clear">
#      </div>
#     </nav>
#     <div id="search" style="display:none">
#      <section class="roundbox type-99">
#       <div class="form-search type-99">
#        <table summary="기간,시장구분,제출구분">
#         <caption>
#          감사보고서 제출 현황 검색
#         </caption>
#         <colgroup>
#          <col width="70"/>
#          <col width="*"/>
#          <col width="70"/>
#          <col width="*"/>
#         </colgroup>
#         <tbody>
#          <tr class="first">
#           <th scope="row">
#            <label for="selDate">
#             기간
#            </label>
#           </th>
#           <td colspan="3">
#            <input checked="checked" class="rad-00" id="periodType1" name="periodType" type="radio" value="M"/>
#            <label for="periodType1">
#             월간
#            </label>
#            <input class="rad-00" id="periodType2" name="periodType" type="radio" value="D"/>
#            <label for="periodType2">
#             일간
#            </label>
#            <input class="txt input-calendar" id="selDate" name="selDate" onfocus="cal_offMask('document.searchForm.selDate'); focusPeriodType(); return false;" onkeyup="chkLmtDate();return false;" title="기간선택 첫번째" type="text" value=""/>
#           </td>
#          </tr>
#          <tr>
#           <th scope="row">
#            <label for="ldMktTpCd1" id="marketType_div">
#             시장구분
#            </label>
#           </th>
#           <td>
#            <input checked="checked" class="rad-00" id="ldMktTpCd1" name="ldMktTpCd" type="radio" value=""/>
#            <label for="ldMktTpCd1">
#             전체
#            </label>
#            <input class="rad-00" id="ldMktTpCd2" name="ldMktTpCd" type="radio" value="1"/>
#            <label for="ldMktTpCd2">
#             유가증권
#            </label>
#            <input class="rad-00" id="ldMktTpCd3" name="ldMktTpCd" type="radio" value="2"/>
#            <label for="ldMktTpCd3">
#             코스닥
#            </label>
#            <input class="rad-00" id="ldMktTpCd4" name="ldMktTpCd" type="radio" value="6"/>
#            <label for="ldMktTpCd3">
#             코넥스
#            </label>
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("01" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('01');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# 		case "10" : method = "searchGeneralMeetingStockholders"; forward ="searchgeneralmeetingstockholders";	//주주총회
# 					break;
# 		case "11" : method = "searchAuditReportReleaseState"; forward ="searchauditreportreleasestate";			//감사보고서 제출 현황
# 					break;
# 		case "12" : method = "searchInsincerityDistribute"; forward ="searchinsinceritydistribute";				//불성실공시법인지정
# 					break;
# 		case "13" : method = "searchTraidingCalendar"; forward ="searchtraidingcalendar";						//트레이딩캘린더
# 					break;
# 	}
#
# 	$('#searchForm > #searchMenu').val(no);
# 	$("#searchForm > #method").val(method);
# 	$("#searchForm > #forward").val(forward);
#
# 	searchForm.ajaxSubmit({
# 		  ajaxUrl : '/common/stockschedule.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnClassActive(no) {
# 	var searchForm = $('#searchForm');
# 	fnClassDelete();
# 	switch(no){
# 		case "01" : searchForm.find('li[id=A]').attr('class', 'first active')
# 					break;
# 		case "02" : searchForm.find('li[id=B]').attr('class', 'active')
# 					break;
# 		case "03" : searchForm.find('li[id=C]').attr('class', 'active')
# 					break;
# 		case "04" : searchForm.find('li[id=D]').attr('class', 'active')
# 					break;
# 		case "05" : searchForm.find('li[id=E]').attr('class', 'active')
# 					break;
# 		case "06" : searchForm.find('li[id=F]').attr('class', 'active')
# 					break;
# 		case "07" : searchForm.find('li[id=G]').attr('class', 'active')
# 					break;
# 		case "08" : searchForm.find('li[id=H]').attr('class', 'active')
# 					break;
# 		case "09" : searchForm.find('li[id=I]').attr('class', 'active')
# 					break;
# 		case "10" : searchForm.find('li[id=J]').attr('class', 'active')
# 					break;
# 		case "11" : searchForm.find('li[id=K]').attr('class', 'active')
# 					break;
# 		case "12" : searchForm.find('li[id=L]').attr('class', 'active')
# 					break;
# 		case "13" : searchForm.find('li[id=M]').attr('class', 'last active')
# 					break;
# 	}
# }
#
# function fnClassDelete() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('li[id=A]').attr('class', 'first');
# 	searchForm.find('li[id=B]').attr('class', '');
# 	searchForm.find('li[id=C]').attr('class', '');
# 	searchForm.find('li[id=D]').attr('class', '');
# 	searchForm.find('li[id=E]').attr('class', '');
# 	searchForm.find('li[id=F]').attr('class', '');
# 	searchForm.find('li[id=G]').attr('class', '');
# 	searchForm.find('li[id=H]').attr('class', '');
# 	searchForm.find('li[id=I]').attr('class', '');
# 	searchForm.find('li[id=J]').attr('class', '');
# 	searchForm.find('li[id=K]').attr('class', '');
# 	searchForm.find('li[id=L]').attr('class', '');
# 	searchForm.find('li[id=M]').attr('class', 'last');
# }
#
# function fnSearchCallBack(data){
# 	$("#contents").empty().append(data);
# 	var menuNum = $("#searchMenu").val();
# 	// 04:액면변경, 05:주식배당, 06:감자, 09:결산실적공시 예정
# 	if(menuNum == '04' || menuNum == '05' || menuNum == '06' || menuNum =='09') {
# 		$("tr:even").addClass("active");
# 	} else {
# 		$("tr:odd").addClass("active");
# 	}
# 	fnLegendTooltip();
# }
#
# function fnYearChange(){
# 	fnSwapImage($('#searchForm').find('select[name=showMonth]').val(), 'click');
# }
#
# function fnSwapImage(val, type){
# 	var searchForm = $('#searchForm');
# 	var month = "";
# 	if (type == "click"){
# 		document.searchForm.periodType[0].checked = true;
# 		document.searchForm.periodType[1].checked = false;
# 		month = val;
# 	} else {
# 		month = searchForm.find('input:hidden[name=nowMonth]').val();
# 	}
#
# 	searchForm.find('select[name=showMonth]').val(month);
#
# 	clearBtnImage();
#
# 	fnMonthActive(month);
#
# 	//기본으로 오늘날짜 세팅해주기
#  	var vDate, vMon, vDay;
# 	vDate = new Date();
# 	vDate.setDate(vDate.getDate());
#
# 	var curYearMonth = String(vDate.getFullYear())+"-"+String(vMon);
#
# 	if( searchForm.find('select[name=selYear]').val()  ==  String(vDate.getFullYear()) && searchForm.find('select[name=showMonth]').val()  == String(vDate.getMonth()+1)) {
#
# 		//-- <10
# 		if ( (vDate.getMonth()+1) < 10 ) vMon = "0"+String(vDate.getMonth()+1);
# 		else vMon = String(vDate.getMonth()+1);
# 		//-- <10
# 		if ( vDate.getDate() < 10 ) vDay = "0"+String(vDate.getDate());
# 		else vDay =String(vDate.getDate());
#
# 		searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + String(vMon) + "-" + String(vDay));
#
# 	} else {
#
# 		if(val < 10) {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-0" + val + "-01");
# 		} else {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + val + "-01");
# 		}
#
# 	}
#
# 	fnSearchInit($('#searchForm > #searchMenu').val());
# 	fnClassActive($('#searchForm > #searchMenu').val());
# }
#
# function fnMonthActive(month){
# 	var searchForm = $('#searchForm');
# 	switch(month){
# 		case "1" : searchForm.find('a[id=january]').attr('class', 'ord-00 active')
# 					break;
# 		case "2" : searchForm.find('a[id=february]').attr('class', 'ord-01 active')
# 					break;
# 		case "3" : searchForm.find('a[id=march]').attr('class', 'ord-02 active')
# 					break;
# 		case "4" : searchForm.find('a[id=april]').attr('class', 'ord-03 active')
# 					break;
# 		case "5" : searchForm.find('a[id=may]').attr('class', 'ord-04 active')
# 					break;
# 		case "6" : searchForm.find('a[id=june]').attr('class', 'ord-05 active')
# 					break;
# 		case "7" : searchForm.find('a[id=july]').attr('class', 'ord-06 active')
# 					break;
# 		case "8" : searchForm.find('a[id=august]').attr('class', 'ord-07 active')
# 					break;
# 		case "9" : searchForm.find('a[id=september]').attr('class', 'ord-08 active')
# 					break;
# 		case "10" : searchForm.find('a[id=october]').attr('class', 'ord-09 active')
# 					break;
# 		case "11" : searchForm.find('a[id=november]').attr('class', 'ord-10 active')
# 					break;
# 		case "12" : searchForm.find('a[id=december]').attr('class', 'ord-11 active')
# 					break;
# 	}
# }
#
# function clearBtnImage(){
# 	var searchForm = $('#searchForm');
# 	searchForm.find('a[id=january]').attr('class', 'ord-00');
# 	searchForm.find('a[id=february]').attr('class', 'ord-01');
# 	searchForm.find('a[id=march]').attr('class', 'ord-02');
# 	searchForm.find('a[id=april]').attr('class', 'ord-03');
# 	searchForm.find('a[id=may]').attr('class', 'ord-04');
# 	searchForm.find('a[id=june]').attr('class', 'ord-05');
# 	searchForm.find('a[id=july]').attr('class', 'ord-06');
# 	searchForm.find('a[id=august]').attr('class', 'ord-07');
# 	searchForm.find('a[id=september]').attr('class', 'ord-08');
# 	searchForm.find('a[id=october]').attr('class', 'ord-09');
# 	searchForm.find('a[id=november]').attr('class', 'ord-10');
# 	searchForm.find('a[id=december]').attr('class', 'ord-11');
# }
#
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(comAbbrv)
# 	$("#searchForm > #repIsuSrtCd").val(isurCd);
# 	fnSearchCorpName($('#searchForm > #searchMenu').val());
# }
#
# function keyEvent(e){
#   if(document.all){
#     if(window.event.keyCode==13){
#     	fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }else{
#     if(e==13){
# 		fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }
# }
#
# function chkLmtDate() {
# 	var dateVal = $("#searchForm").find("input:text[name=selDate]").val();
# 	if(dateVal.length == 8){
# 		if(dateVal.substring(0,4) < 1999){
# 			alert("1999년부터 조회 가능합니다.");
# 			$("#searchForm").find("input:text[name=selDate]").val("1999-01-01");
# 			return false;
# 		}
# 	}
#
# 	//날짜포멧 공통함수
# 	chkDate('document.searchForm.selDate');
# }
#
# function focusPeriodType() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('input:radio[id=periodType1]').attr('checked', false);
# 	searchForm.find('input:radio[id=periodType2]').attr('checked', true);
# 	$('#searchForm > #enterFlag').val("");
# }
#
# function fnCompanySearch(tabIndex, isurCd){
# 	$('#searchForm > #searchCodeType').val("number");
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(isurCd);
#
# 	//유상증자
#   if(tabIndex == "01"){
# 	fnSearchInit("02");
# 	fnClassActive("02");
#   //무상증자
#   }else if(tabIndex == "02"){
# 	fnSearchInit("03");
# 	fnClassActive("03");
#   //액면변경
#   }else if(tabIndex == "03"){
# 	fnSearchInit("04");
# 	fnClassActive("04");
#   //감자
#   }else if(tabIndex == "04"){
# 	fnSearchInit("06");
# 	fnClassActive("06");
#   //분할/합병
#   }else if(tabIndex == "05" || tabIndex == "11"){
# 	fnSearchInit("07");
# 	fnClassActive("07");
#   //상호변경
#   }else if(tabIndex == "07"){
# 	fnSearchInit("08");
# 	fnClassActive("08");
#   //주주총회
#   }else if(tabIndex == "08"){
# 	fnSearchInit("10");
# 	fnClassActive("10");
#   //불성실공시법인지정
#   }else if(tabIndex == "09"){
# 	fnSearchInit("12");
# 	fnClassActive("12");
#   //수직배당
#   }else if(tabIndex == "12"){
# 	fnSearchInit("05");
# 	fnClassActive("05");
#   //결산실적공시 예정
#   }else if(tabIndex == "13"){
# 	fnSearchInit("09");
# 	fnClassActive("09");
#   //감사보고서 제출 현황
#   }else if(tabIndex == "14"){
# 	fnSearchInit("11");
# 	fnClassActive("11");
#   }
# }
#
# //검색버튼 눌렀을경우 회사명 먼저 조회한다
# function fnSearchCorpName(no){
# 	var	val = $("#searchForm").find("input:text[name=searchCorpName]").val();
# 	if(val == ""){
# 		$("#searchForm > #repIsuSrtCd").val("");
# 	}
# 	if(val != "" && val != ("회사명/코드")){
# 		$('#searchForm > #searchMenu').val(no);
# 		fnAKCKwdSearchCorpName();
# 	}else{
# 		fnSearch(no);
# 	}
# }
#
# function fnSearchCorpNameAllCallBack(items)  {
# 	$("#searchForm > #repIsuSrtCd").val('');
# 	if(items.length == 1) {
# 		$("#searchForm > #repIsuSrtCd").val(items[0].isurcd + "0");
# 		fnSearchCorpCode();
# 		fnSetCookieCrop(items);
# 	} else {
# 		fnSearchCorpCode();
# 	}
# }
#
# //회사명 조회 결과
# function fnSearchCorpCode(){
# 	var repIsuSrtCd = $("#searchForm > #repIsuSrtCd").val();
#
# 	if(repIsuSrtCd == ""){
# 		alert("조회한 회사명이 존재하지 않습니다. \n정확한 회사명을 입력해 주세요. \n회사명이 정확하지 않으시면 회사명 검색을 이용해주세요.");
# 		$("#searchCorpName").val("");
# 	}
# 	fnSearch($('#searchForm > #searchMenu').val());
# }
#
# function fnTextInit() {
# 	if($("#searchCorpName").val() == "회사명/코드") {
# 		$("#searchCorpName").val("");
# 	}
# }
#   </script>
#   <footer class="popup">
#    <div class="btn-group type-98">
#     <a class="btn-sprite type-98 vmiddle" href="#myclose" onclick="fnPopClose(); return false;" title="닫기">
#      <span>
#       닫 기
#      </span>
#     </a>
#    </div>
#   </footer>
#   <!-- 범례 START -->
#   <div id="marketSection" style="position:absolute; display:none">
#    <section class="icn_tbox" style="width:400px;top:-30px; left:10px">
#     <ul>
#      <li>
#       <img alt="유가증권" class="vmiddle" src="../images/common/icn_t_yu.gif"/>
#       유가증권
#      </li>
#      <li>
#       <img alt="코스닥" class="vmiddle" src="../images/common/icn_t_ko.gif"/>
#       코스닥
#      </li>
#      <li>
#       <img alt="코넥스" class="vmiddle" src="../images/common/icn_t_konex.gif"/>
#       코넥스
#      </li>
#      <li>
#       <img alt="관리종목" class="vmiddle" src="../images/common/icn_t_kwan.gif"/>
#       관리종목
#      </li>
#      <li>
#       <img alt="투자주의환기종목" class="vmiddle" src="../images/common/icn_t_hwan.gif"/>
#       투자주의환기종목
#      </li>
#      <li>
#       <img alt="불성실공시법인" class="vmiddle" src="../images/common/icn_t_bul.gif"/>
#       불성실공시법인
#      </li>
#      <li>
#       <img alt="폐지법인" class="vmiddle" src="../images/common/icn_t_pe.gif"/>
#       폐지법인
#      </li>
#      <li>
#       <img alt="KTOP30" class="vmiddle" src="../images/common/icn_t_ktop.gif"/>
#       KTOP30
#      </li>
#      <li>
#       <img alt="KOSPI200" class="vmiddle" src="../images/common/icn_t_k200.gif"/>
#       KOSPI200
#      </li>
#      <li>
#       <img alt="KOSDAQ150" class="vmiddle" src="../images/common/icn_t_q150.gif"/>
#       KOSDAQ150
#      </li>
#      <li>
#       <img alt="KRX300" class="vmiddle" src="../images/common/icn_t_x300.gif"/>
#       KRX300
#      </li>
#      <li>
#       <img alt="정정있음" class="vmiddle" src="../images/common/icn_t_jung.gif"/>
#       정정있음
#      </li>
#      <li>
#       <img alt="투자주의" class="vmiddle" src="../images/common/icn_t_joo.gif"/>
#       투자주의
#      </li>
#      <li>
#       <img alt="투자경고" class="vmiddle" src="../images/common/icn_t_kyung.gif"/>
#       투자경고
#      </li>
#      <li>
#       <img alt="투자위험" class="vmiddle" src="../images/common/icn_t_wii.gif"/>
#       투자위험
#      </li>
#     </ul>
#     <div class="clear">
#     </div>
#     <img alt="" class="tl" src="../images/common/icn_tbox_tl.png"/>
#     <img alt="" class="bl" src="../images/common/icn_tbox_bl.gif"/>
#     <img alt="" class="tr" src="../images/common/icn_tbox_tr.gif"/>
#     <img alt="" class="br" src="../images/common/icn_tbox_br.gif"/>
#     <div class="tm">
#     </div>
#     <div class="lm">
#     </div>
#     <div class="bm">
#     </div>
#     <div class="rm">
#     </div>
#    </section>
#   </div>
#   <!-- 범례 END -->
#   <div class="loading" id="dialog-loading" style="display: none;" title="자료를 조회 중입니다.">
#    <span>
#     <img src="/images/loader/ajax-loader01.gif"/>
#    </span>
#   </div>
#  </body>
# </html>
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="kr" http-equiv="content-language"/>
#   <meta content="text/css" http-equiv="content-style-type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="no" http-equiv="imagetoolbar"/>
#   <meta content="(c)2012" name="copyright"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="description"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="keywords"/>
#   <title>
#    대한민국 대표 기업공시채널 KIND
#   </title>
#   <link href="../js/jquery/themes-base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/default_new.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/common.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/popup.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
#   <script src="../js/trans.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="../js/common.js" type="text/javascript">
#   </script>
#   <script src="../js/common-pop.js?version=20220624" type="text/javascript">
#   </script>
#   <script src="../js/common-ajax.js" type="text/javascript">
#   </script>
#   <script src="../js/JCommon.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="pop">
#   <header class="popup">
#    <h1 class="ttl type-99" id="title">
#     증시일정
#    </h1>
#   </header>
#   <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
#    <input id="method" name="method" type="hidden"/>
#    <input id="forward" name="forward" type="hidden"/>
#    <input id="searchCodeType" name="searchCodeType" type="hidden"/>
#    <!--number:법인코드 char:법인명-->
#    <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden"/>
#    <!--법인코드-->
#    <input id="menuIndex" name="menuIndex" type="hidden"/>
#    <!--검색할 페이지-->
#    <input id="selMonth" name="selMonth" type="hidden"/>
#    <!--월-->
#    <input id="selDay" name="selDay" type="hidden"/>
#    <!--일자-->
#    <input id="enterFlag" name="enterFlag" type="hidden"/>
#    <input id="searchMenu" name="searchMenu" type="hidden" value="01"/>
#    <input id="nowYear" name="nowYear" type="hidden" value="2023"/>
#    <input id="nowMonth" name="nowMonth" type="hidden" value="11"/>
#    <!-- 리스트검색 -->
#    <section class="contents popup">
#     <section class="roundbox type-99">
#      <div class="form-search type-99">
#       <table summary="검색">
#        <caption>
#         증시일정
#        </caption>
#        <colgroup>
#         <col width="50"/>
#         <col width="200"/>
#         <col width="90"/>
#         <col width="*"/>
#        </colgroup>
#        <tbody>
#         <tr class="first">
#          <th scope="row">
#           <label for="name">
#            회사명
#           </label>
#          </th>
#          <td>
#           <input class="middle" id="searchCorpName" name="searchCorpName" onclick="fnTextInit(); return false;" type="text"/>
#           <a href="#searchCorp" onclick="findCompanyName();return false;" title="회사명찾기">
#            <img alt="회사명찾기" class="vtop" id="searchCorp" src="../../images/common/btn_zoom.gif"/>
#           </a>
#          </td>
#          <td>
#           <select class="select" id="selYear" name="selYear" onchange="fnYearChange()">
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option selected="selected" value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#            <option value="2025">
#             2025
#            </option>
#           </select>
#           년
#           <select class="select" id="showMonth" name="showMonth" style="display:none">
#            <option value="1">
#             1
#            </option>
#            <option value="2">
#             2
#            </option>
#            <option value="3">
#             3
#            </option>
#            <option value="4">
#             4
#            </option>
#            <option value="5">
#             5
#            </option>
#            <option value="6">
#             6
#            </option>
#            <option value="7">
#             7
#            </option>
#            <option value="8">
#             8
#            </option>
#            <option value="9">
#             9
#            </option>
#            <option value="10">
#             10
#            </option>
#            <option selected="selected" value="11">
#             11
#            </option>
#            <option value="12">
#             12
#            </option>
#           </select>
#          </td>
#          <td>
#           <ul class="btn-set months">
#            <li>
#             <a class="ord-00" href="#" id="january" onclick="fnSwapImage('1', 'click')" title="1월">
#              <span>
#               1월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-01" href="#" id="february" onclick="fnSwapImage('2', 'click')" title="2월">
#              <span>
#               2월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-02" href="#" id="march" onclick="fnSwapImage('3', 'click')" title="3월">
#              <span>
#               3월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-03" href="#" id="april" onclick="fnSwapImage('4', 'click')" title="4월">
#              <span>
#               4월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-04" href="#" id="may" onclick="fnSwapImage('5', 'click')" title="5월">
#              <span>
#               5월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-05" href="#" id="june" onclick="fnSwapImage('6', 'click')" title="6월">
#              <span>
#               6월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-06" href="#" id="july" onclick="fnSwapImage('7', 'click')" title="7월">
#              <span>
#               7월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-07" href="#" id="august" onclick="fnSwapImage('8', 'click')" title="8월">
#              <span>
#               8월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-08" href="#" id="september" onclick="fnSwapImage('9', 'click')" title="9월">
#              <span>
#               9월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-09" href="#" id="october" onclick="fnSwapImage('10', 'click')" title="10월">
#              <span>
#               10월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-10" href="#" id="november" onclick="fnSwapImage('11', 'click')" title="11월">
#              <span>
#               11월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-11" href="#" id="december" onclick="fnSwapImage('12', 'click')" title="12월">
#              <span>
#               12월
#              </span>
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#      <img alt="" class="tl" src="../images/common/rbox-type-99-tl.png"/>
#      <img alt="" class="bl" src="../images/common/rbox-type-99-bl.png"/>
#      <img alt="" class="tr" src="../images/common/rbox-type-99-tr.png"/>
#      <img alt="" class="br" src="../images/common/rbox-type-99-br.png"/>
#      <div class="tm">
#      </div>
#      <div class="lm">
#      </div>
#      <div class="bm">
#      </div>
#      <div class="rm">
#      </div>
#     </section>
#     <nav class="tabgroup type-97 mt10">
#      <ul>
#       <li id="A">
#        <a href="#" onclick="fnSearchInit('01'); fnClassActive('01'); return false;" title="종합">
#         <span>
#          종합
#         </span>
#        </a>
#       </li>
#       <li id="B">
#        |
#        <a href="#" onclick="fnSearchInit('02'); fnClassActive('02'); return false;" title="유상종자">
#         <span>
#          유상증자
#         </span>
#        </a>
#       </li>
#       <li id="C">
#        |
#        <a href="#" onclick="fnSearchInit('03'); fnClassActive('03'); return false;" title="무상종자">
#         <span>
#          무상증자
#         </span>
#        </a>
#       </li>
#       <li id="D">
#        |
#        <a href="#" onclick="fnSearchInit('04'); fnClassActive('04'); return false;" title="액면변경">
#         <span>
#          액면변경
#         </span>
#        </a>
#       </li>
#       <li id="E">
#        |
#        <a href="#" onclick="fnSearchInit('05'); fnClassActive('05'); return false;" title="주식배당">
#         <span>
#          주식배당
#         </span>
#        </a>
#       </li>
#       <li id="F">
#        |
#        <a href="#" onclick="fnSearchInit('06'); fnClassActive('06'); return false;" title="감자">
#         <span>
#          감자
#         </span>
#        </a>
#       </li>
#       <li id="G">
#        |
#        <a href="#" onclick="fnSearchInit('07'); fnClassActive('07'); return false;" title="분할/합병">
#         <span>
#          분할/합병
#         </span>
#        </a>
#       </li>
#       <li id="H">
#        |
#        <a href="#" onclick="fnSearchInit('08'); fnClassActive('08'); return false;" title="상호변경">
#         <span>
#          상호변경
#         </span>
#        </a>
#       </li>
#       <li id="I">
#        |
#        <a href="#" onclick="fnSearchInit('09'); fnClassActive('09'); return false;" title="결산실적공시 예정">
#         <span>
#          결산실적공시 예정
#         </span>
#        </a>
#       </li>
#       <li id="J">
#        |
#        <a href="#" onclick="fnSearchInit('10'); fnClassActive('10'); return false;" title="주주총회">
#         <span>
#          주주총회
#         </span>
#        </a>
#       </li>
#       <li id="K">
#        |
#        <a href="#" onclick="fnSearchInit('11'); fnClassActive('11'); return false;" title="감사보고서 제출 현황">
#         <span>
#          감사보고서 제출 현황
#         </span>
#        </a>
#       </li>
#       <li id="L">
#        |
#        <a href="#" onclick="fnSearchInit('12'); fnClassActive('12'); return false;" title="불성실공시법인지정">
#         <span>
#          불성실공시법인지정
#         </span>
#        </a>
#       </li>
#       <li id="M">
#        |
#        <a href="#" onclick="fnSearchInit('13'); fnClassActive('13'); return false;" title="트레이딩캘린더">
#         <span>
#          트레이딩캘린더
#         </span>
#        </a>
#       </li>
#      </ul>
#      <div class="clear">
#      </div>
#     </nav>
#     <div id="search" style="display:none">
#      <section class="roundbox type-99">
#       <div class="form-search type-99">
#        <table summary="기간,시장구분,제출구분">
#         <caption>
#          감사보고서 제출 현황 검색
#         </caption>
#         <colgroup>
#          <col width="70"/>
#          <col width="*"/>
#          <col width="70"/>
#          <col width="*"/>
#         </colgroup>
#         <tbody>
#          <tr class="first">
#           <th scope="row">
#            <label for="selDate">
#             기간
#            </label>
#           </th>
#           <td colspan="3">
#            <input checked="checked" class="rad-00" id="periodType1" name="periodType" type="radio" value="M"/>
#            <label for="periodType1">
#             월간
#            </label>
#            <input class="rad-00" id="periodType2" name="periodType" type="radio" value="D"/>
#            <label for="periodType2">
#             일간
#            </label>
#            <input class="txt input-calendar" id="selDate" name="selDate" onfocus="cal_offMask('document.searchForm.selDate'); focusPeriodType(); return false;" onkeyup="chkLmtDate();return false;" title="기간선택 첫번째" type="text" value=""/>
#           </td>
#          </tr>
#          <tr>
#           <th scope="row">
#            <label for="ldMktTpCd1" id="marketType_div">
#             시장구분
#            </label>
#           </th>
#           <td>
#            <input checked="checked" class="rad-00" id="ldMktTpCd1" name="ldMktTpCd" type="radio" value=""/>
#            <label for="ldMktTpCd1">
#             전체
#            </label>
#            <input class="rad-00" id="ldMktTpCd2" name="ldMktTpCd" type="radio" value="1"/>
#            <label for="ldMktTpCd2">
#             유가증권
#            </label>
#            <input class="rad-00" id="ldMktTpCd3" name="ldMktTpCd" type="radio" value="2"/>
#            <label for="ldMktTpCd3">
#             코스닥
#            </label>
#            <input class="rad-00" id="ldMktTpCd4" name="ldMktTpCd" type="radio" value="6"/>
#            <label for="ldMktTpCd3">
#             코넥스
#            </label>
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("02" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('02');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# ...
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("012" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('012');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# 		case "10" : method = "searchGeneralMeetingStockholders"; forward ="searchgeneralmeetingstockholders";	//주주총회
# 					break;
# 		case "11" : method = "searchAuditReportReleaseState"; forward ="searchauditreportreleasestate";			//감사보고서 제출 현황
# 					break;
# 		case "12" : method = "searchInsincerityDistribute"; forward ="searchinsinceritydistribute";				//불성실공시법인지정
# 					break;
# 		case "13" : method = "searchTraidingCalendar"; forward ="searchtraidingcalendar";						//트레이딩캘린더
# 					break;
# 	}
#
# 	$('#searchForm > #searchMenu').val(no);
# 	$("#searchForm > #method").val(method);
# 	$("#searchForm > #forward").val(forward);
#
# 	searchForm.ajaxSubmit({
# 		  ajaxUrl : '/common/stockschedule.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnClassActive(no) {
# 	var searchForm = $('#searchForm');
# 	fnClassDelete();
# 	switch(no){
# 		case "01" : searchForm.find('li[id=A]').attr('class', 'first active')
# 					break;
# 		case "02" : searchForm.find('li[id=B]').attr('class', 'active')
# 					break;
# 		case "03" : searchForm.find('li[id=C]').attr('class', 'active')
# 					break;
# 		case "04" : searchForm.find('li[id=D]').attr('class', 'active')
# 					break;
# 		case "05" : searchForm.find('li[id=E]').attr('class', 'active')
# 					break;
# 		case "06" : searchForm.find('li[id=F]').attr('class', 'active')
# 					break;
# 		case "07" : searchForm.find('li[id=G]').attr('class', 'active')
# 					break;
# 		case "08" : searchForm.find('li[id=H]').attr('class', 'active')
# 					break;
# 		case "09" : searchForm.find('li[id=I]').attr('class', 'active')
# 					break;
# 		case "10" : searchForm.find('li[id=J]').attr('class', 'active')
# 					break;
# 		case "11" : searchForm.find('li[id=K]').attr('class', 'active')
# 					break;
# 		case "12" : searchForm.find('li[id=L]').attr('class', 'active')
# 					break;
# 		case "13" : searchForm.find('li[id=M]').attr('class', 'last active')
# 					break;
# 	}
# }
#
# function fnClassDelete() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('li[id=A]').attr('class', 'first');
# 	searchForm.find('li[id=B]').attr('class', '');
# 	searchForm.find('li[id=C]').attr('class', '');
# 	searchForm.find('li[id=D]').attr('class', '');
# 	searchForm.find('li[id=E]').attr('class', '');
# 	searchForm.find('li[id=F]').attr('class', '');
# 	searchForm.find('li[id=G]').attr('class', '');
# 	searchForm.find('li[id=H]').attr('class', '');
# 	searchForm.find('li[id=I]').attr('class', '');
# 	searchForm.find('li[id=J]').attr('class', '');
# 	searchForm.find('li[id=K]').attr('class', '');
# 	searchForm.find('li[id=L]').attr('class', '');
# 	searchForm.find('li[id=M]').attr('class', 'last');
# }
#
# function fnSearchCallBack(data){
# 	$("#contents").empty().append(data);
# 	var menuNum = $("#searchMenu").val();
# 	// 04:액면변경, 05:주식배당, 06:감자, 09:결산실적공시 예정
# 	if(menuNum == '04' || menuNum == '05' || menuNum == '06' || menuNum =='09') {
# 		$("tr:even").addClass("active");
# 	} else {
# 		$("tr:odd").addClass("active");
# 	}
# 	fnLegendTooltip();
# }
#
# function fnYearChange(){
# 	fnSwapImage($('#searchForm').find('select[name=showMonth]').val(), 'click');
# }
#
# function fnSwapImage(val, type){
# 	var searchForm = $('#searchForm');
# 	var month = "";
# 	if (type == "click"){
# 		document.searchForm.periodType[0].checked = true;
# 		document.searchForm.periodType[1].checked = false;
# 		month = val;
# 	} else {
# 		month = searchForm.find('input:hidden[name=nowMonth]').val();
# 	}
#
# 	searchForm.find('select[name=showMonth]').val(month);
#
# 	clearBtnImage();
#
# 	fnMonthActive(month);
#
# 	//기본으로 오늘날짜 세팅해주기
#  	var vDate, vMon, vDay;
# 	vDate = new Date();
# 	vDate.setDate(vDate.getDate());
#
# 	var curYearMonth = String(vDate.getFullYear())+"-"+String(vMon);
#
# 	if( searchForm.find('select[name=selYear]').val()  ==  String(vDate.getFullYear()) && searchForm.find('select[name=showMonth]').val()  == String(vDate.getMonth()+1)) {
#
# 		//-- <10
# 		if ( (vDate.getMonth()+1) < 10 ) vMon = "0"+String(vDate.getMonth()+1);
# 		else vMon = String(vDate.getMonth()+1);
# 		//-- <10
# 		if ( vDate.getDate() < 10 ) vDay = "0"+String(vDate.getDate());
# 		else vDay =String(vDate.getDate());
#
# 		searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + String(vMon) + "-" + String(vDay));
#
# 	} else {
#
# 		if(val < 10) {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-0" + val + "-01");
# 		} else {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + val + "-01");
# 		}
#
# 	}
#
# 	fnSearchInit($('#searchForm > #searchMenu').val());
# 	fnClassActive($('#searchForm > #searchMenu').val());
# }
#
# function fnMonthActive(month){
# 	var searchForm = $('#searchForm');
# 	switch(month){
# 		case "1" : searchForm.find('a[id=january]').attr('class', 'ord-00 active')
# 					break;
# 		case "2" : searchForm.find('a[id=february]').attr('class', 'ord-01 active')
# 					break;
# 		case "3" : searchForm.find('a[id=march]').attr('class', 'ord-02 active')
# 					break;
# 		case "4" : searchForm.find('a[id=april]').attr('class', 'ord-03 active')
# 					break;
# 		case "5" : searchForm.find('a[id=may]').attr('class', 'ord-04 active')
# 					break;
# 		case "6" : searchForm.find('a[id=june]').attr('class', 'ord-05 active')
# 					break;
# 		case "7" : searchForm.find('a[id=july]').attr('class', 'ord-06 active')
# 					break;
# 		case "8" : searchForm.find('a[id=august]').attr('class', 'ord-07 active')
# 					break;
# 		case "9" : searchForm.find('a[id=september]').attr('class', 'ord-08 active')
# 					break;
# 		case "10" : searchForm.find('a[id=october]').attr('class', 'ord-09 active')
# 					break;
# 		case "11" : searchForm.find('a[id=november]').attr('class', 'ord-10 active')
# 					break;
# 		case "12" : searchForm.find('a[id=december]').attr('class', 'ord-11 active')
# 					break;
# 	}
# }
#
# function clearBtnImage(){
# 	var searchForm = $('#searchForm');
# 	searchForm.find('a[id=january]').attr('class', 'ord-00');
# 	searchForm.find('a[id=february]').attr('class', 'ord-01');
# 	searchForm.find('a[id=march]').attr('class', 'ord-02');
# 	searchForm.find('a[id=april]').attr('class', 'ord-03');
# 	searchForm.find('a[id=may]').attr('class', 'ord-04');
# 	searchForm.find('a[id=june]').attr('class', 'ord-05');
# 	searchForm.find('a[id=july]').attr('class', 'ord-06');
# 	searchForm.find('a[id=august]').attr('class', 'ord-07');
# 	searchForm.find('a[id=september]').attr('class', 'ord-08');
# 	searchForm.find('a[id=october]').attr('class', 'ord-09');
# 	searchForm.find('a[id=november]').attr('class', 'ord-10');
# 	searchForm.find('a[id=december]').attr('class', 'ord-11');
# }
#
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(comAbbrv)
# 	$("#searchForm > #repIsuSrtCd").val(isurCd);
# 	fnSearchCorpName($('#searchForm > #searchMenu').val());
# }
#
# function keyEvent(e){
#   if(document.all){
#     if(window.event.keyCode==13){
#     	fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }else{
#     if(e==13){
# 		fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }
# }
#
# function chkLmtDate() {
# 	var dateVal = $("#searchForm").find("input:text[name=selDate]").val();
# 	if(dateVal.length == 8){
# 		if(dateVal.substring(0,4) < 1999){
# 			alert("1999년부터 조회 가능합니다.");
# 			$("#searchForm").find("input:text[name=selDate]").val("1999-01-01");
# 			return false;
# 		}
# 	}
#
# 	//날짜포멧 공통함수
# 	chkDate('document.searchForm.selDate');
# }
#
# function focusPeriodType() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('input:radio[id=periodType1]').attr('checked', false);
# 	searchForm.find('input:radio[id=periodType2]').attr('checked', true);
# 	$('#searchForm > #enterFlag').val("");
# }
#
# function fnCompanySearch(tabIndex, isurCd){
# 	$('#searchForm > #searchCodeType').val("number");
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(isurCd);
#
# 	//유상증자
#   if(tabIndex == "01"){
# 	fnSearchInit("02");
# 	fnClassActive("02");
#   //무상증자
#   }else if(tabIndex == "02"){
# 	fnSearchInit("03");
# 	fnClassActive("03");
#   //액면변경
#   }else if(tabIndex == "03"){
# 	fnSearchInit("04");
# 	fnClassActive("04");
#   //감자
#   }else if(tabIndex == "04"){
# 	fnSearchInit("06");
# 	fnClassActive("06");
#   //분할/합병
#   }else if(tabIndex == "05" || tabIndex == "11"){
# 	fnSearchInit("07");
# 	fnClassActive("07");
#   //상호변경
#   }else if(tabIndex == "07"){
# 	fnSearchInit("08");
# 	fnClassActive("08");
#   //주주총회
#   }else if(tabIndex == "08"){
# 	fnSearchInit("10");
# 	fnClassActive("10");
#   //불성실공시법인지정
#   }else if(tabIndex == "09"){
# 	fnSearchInit("12");
# 	fnClassActive("12");
#   //수직배당
#   }else if(tabIndex == "12"){
# 	fnSearchInit("05");
# 	fnClassActive("05");
#   //결산실적공시 예정
#   }else if(tabIndex == "13"){
# 	fnSearchInit("09");
# 	fnClassActive("09");
#   //감사보고서 제출 현황
#   }else if(tabIndex == "14"){
# 	fnSearchInit("11");
# 	fnClassActive("11");
#   }
# }
#
# //검색버튼 눌렀을경우 회사명 먼저 조회한다
# function fnSearchCorpName(no){
# 	var	val = $("#searchForm").find("input:text[name=searchCorpName]").val();
# 	if(val == ""){
# 		$("#searchForm > #repIsuSrtCd").val("");
# 	}
# 	if(val != "" && val != ("회사명/코드")){
# 		$('#searchForm > #searchMenu').val(no);
# 		fnAKCKwdSearchCorpName();
# 	}else{
# 		fnSearch(no);
# 	}
# }
#
# function fnSearchCorpNameAllCallBack(items)  {
# 	$("#searchForm > #repIsuSrtCd").val('');
# 	if(items.length == 1) {
# 		$("#searchForm > #repIsuSrtCd").val(items[0].isurcd + "0");
# 		fnSearchCorpCode();
# 		fnSetCookieCrop(items);
# 	} else {
# 		fnSearchCorpCode();
# 	}
# }
#
# //회사명 조회 결과
# function fnSearchCorpCode(){
# 	var repIsuSrtCd = $("#searchForm > #repIsuSrtCd").val();
#
# 	if(repIsuSrtCd == ""){
# 		alert("조회한 회사명이 존재하지 않습니다. \n정확한 회사명을 입력해 주세요. \n회사명이 정확하지 않으시면 회사명 검색을 이용해주세요.");
# 		$("#searchCorpName").val("");
# 	}
# 	fnSearch($('#searchForm > #searchMenu').val());
# }
#
# function fnTextInit() {
# 	if($("#searchCorpName").val() == "회사명/코드") {
# 		$("#searchCorpName").val("");
# 	}
# }
#   </script>
#   <footer class="popup">
#    <div class="btn-group type-98">
#     <a class="btn-sprite type-98 vmiddle" href="#myclose" onclick="fnPopClose(); return false;" title="닫기">
#      <span>
#       닫 기
#      </span>
#     </a>
#    </div>
#   </footer>
#   <!-- 범례 START -->
#   <div id="marketSection" style="position:absolute; display:none">
#    <section class="icn_tbox" style="width:400px;top:-30px; left:10px">
#     <ul>
#      <li>
#       <img alt="유가증권" class="vmiddle" src="../images/common/icn_t_yu.gif"/>
#       유가증권
#      </li>
#      <li>
#       <img alt="코스닥" class="vmiddle" src="../images/common/icn_t_ko.gif"/>
#       코스닥
#      </li>
#      <li>
#       <img alt="코넥스" class="vmiddle" src="../images/common/icn_t_konex.gif"/>
#       코넥스
#      </li>
#      <li>
#       <img alt="관리종목" class="vmiddle" src="../images/common/icn_t_kwan.gif"/>
#       관리종목
#      </li>
#      <li>
#       <img alt="투자주의환기종목" class="vmiddle" src="../images/common/icn_t_hwan.gif"/>
#       투자주의환기종목
#      </li>
#      <li>
#       <img alt="불성실공시법인" class="vmiddle" src="../images/common/icn_t_bul.gif"/>
#       불성실공시법인
#      </li>
#      <li>
#       <img alt="폐지법인" class="vmiddle" src="../images/common/icn_t_pe.gif"/>
#       폐지법인
#      </li>
#      <li>
#       <img alt="KTOP30" class="vmiddle" src="../images/common/icn_t_ktop.gif"/>
#       KTOP30
#      </li>
#      <li>
#       <img alt="KOSPI200" class="vmiddle" src="../images/common/icn_t_k200.gif"/>
#       KOSPI200
#      </li>
#      <li>
#       <img alt="KOSDAQ150" class="vmiddle" src="../images/common/icn_t_q150.gif"/>
#       KOSDAQ150
#      </li>
#      <li>
#       <img alt="KRX300" class="vmiddle" src="../images/common/icn_t_x300.gif"/>
#       KRX300
#      </li>
#      <li>
#       <img alt="정정있음" class="vmiddle" src="../images/common/icn_t_jung.gif"/>
#       정정있음
#      </li>
#      <li>
#       <img alt="투자주의" class="vmiddle" src="../images/common/icn_t_joo.gif"/>
#       투자주의
#      </li>
#      <li>
#       <img alt="투자경고" class="vmiddle" src="../images/common/icn_t_kyung.gif"/>
#       투자경고
#      </li>
#      <li>
#       <img alt="투자위험" class="vmiddle" src="../images/common/icn_t_wii.gif"/>
#       투자위험
#      </li>
#     </ul>
#     <div class="clear">
#     </div>
#     <img alt="" class="tl" src="../images/common/icn_tbox_tl.png"/>
#     <img alt="" class="bl" src="../images/common/icn_tbox_bl.gif"/>
#     <img alt="" class="tr" src="../images/common/icn_tbox_tr.gif"/>
#     <img alt="" class="br" src="../images/common/icn_tbox_br.gif"/>
#     <div class="tm">
#     </div>
#     <div class="lm">
#     </div>
#     <div class="bm">
#     </div>
#     <div class="rm">
#     </div>
#    </section>
#   </div>
#   <!-- 범례 END -->
#   <div class="loading" id="dialog-loading" style="display: none;" title="자료를 조회 중입니다.">
#    <span>
#     <img src="/images/loader/ajax-loader01.gif"/>
#    </span>
#   </div>
#  </body>
# </html>

# %%
import requests
from io import BytesIO
import pandas as pd


# OTP 생성을 위한 요청
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
otp_data = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': f'0{i}',
        # 'searchMenu': '06',
        # 'nowYear': '2023',
        # 'nowMonth': '11',
        'searchCorpName': '회사명/코드',
        'selYear': '2023',
        'showMonth': f'{i}',
        'periodType': 'M',
        'selDate': f'2023-0{i}-01', 
        'submitFlagYn': 'N'
    }
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}
otp_response = requests.post(otp_url, data=otp_data, headers=headers)

# %%
otp_response.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n<article class="scrarea type-00">\r\n\t<h3 class="ttl type-39">* <strong>2023</strong>년 <strong>01</strong>월 <em>감자 일정</em></h3>\r\n\t<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">\r\n\t\t<caption>목록</caption>\r\n\t\t<colgroup>\r\n\t\t\t<col width="10%" />\r\n\t\t\t<col width="16%" />\r\n\t\t\t<col width="7%" />\r\n\t\t\t<col width="8%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="15%" />\r\n\t\t\t<col width="*%" />\r\n\t\t</colgroup>\r\n\t\t<thead>\r\n\t\t\t<tr class="first">\r\n\t\t\t\t<th rowspan="2" class="first" scope="col">감자<br />기준일</th>\r\n\t\t\t\t<th rowspan="2" scope="col">회사명</th>\r\n\t\t\t\t<th rowspan="2" scope="col">종목코드</th>\r\n\t\t\t\t<th rowspan="2" scope="col">감자비율(%)</th>\r\n\t\t\t\t<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>\r\n\t\t\t\t<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>\r\n\t\t\t\t<th rowspan="2" scope="col">구주권 제출기간</th>\r\n\t\t\t\t<th rowspan="2" scope="col">원문보기</th>\r\n\t\t\t</tr>\r\n\t\t\t<tr>\r\n\t\t\t\t<th class="thc" scope="col">보통주</th>\r\n\t\t\t\t<th class="thc" scope="col">우선주</th>\r\n\t\t\t\t<th class="thc" scope="col">보통주</th>\r\n\t\t\t\t<th class="thc" scope="col">우선주</th>\r\n\t\t\t</tr>\r\n\t\t</thead>\r\n\t\t<tbody>\r\n\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t<tr class="first">\r\n\t\t\t\t\t\t<td class="first txc">2023-01-25</td>\r\n\t\t\t\t\t\t<td><img src=\'/images/common/icn_t_ko.gif\' class=\'vmiddle legend\' alt=\'코스닥\'> <a id="companysum" href="#companysum" onclick="companysummary_open(\'26354\'); return false;" title=\'어스앤에어로스페이스\'> 어스앤에어로스페이스</a> <img src=\'/images/common/icn_t_kwan.gif\' class=\'vmiddle legend\' alt=\'관리종목\'/> <img src=\'/images/common/icn_t_hwan.gif\' class=\'vmiddle legend\' alt=\'투자주의환기종목\'> </td>\r\n\t\t\t\t\t\t<td class="txc">263540</td>\r\n\t\t\t\t\t\t<td class="txr">                      80.00</td>\r\n\t\t\t\t\t\t<td class="txr">                   7,733,747</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txr">                   2,102,547</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txc"></td>\r\n\t\t\t\t\t\t<td class="txc">\r\n\t\t\t\t\t\t\t<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer(\'20221215001394\',\'\'); return false;"></a>\r\n\t\t\t\t\t\t</td>\r\n\t\t\t\t\t</tr>\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t<tr class="">\r\n\t\t\t\t\t\t<td class="first txc">2023-01-27</td>\r\n\t\t\t\t\t\t<td><img src=\'/images/common/icn_t_ko.gif\' class=\'vmiddle legend\' alt=\'코스닥\'> <a id="companysum" href="#companysum" onclick="companysummary_open(\'17878\'); return false;" title=\'일월지엠엘\'> 일월지엠엘</a> <img src=\'/images/common/icn_t_kwan.gif\' class=\'vmiddle legend\' alt=\'관리종목\'/> <img src=\'/images/common/icn_t_hwan.gif\' class=\'vmiddle legend\' alt=\'투자주의환기종목\'> </td>\r\n\t\t\t\t\t\t<td class="txc">178780</td>\r\n\t\t\t\t\t\t<td class="txr">                      80.00</td>\r\n\t\t\t\t\t\t<td class="txr">                  34,820,984</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txr">                   6,964,196</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txc"></td>\r\n\t\t\t\t\t\t<td class="txc">\r\n\t\t\t\t\t\t\t<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer(\'20230217000855\',\'\'); return false;"></a>\r\n\t\t\t\t\t\t</td>\r\n\t\t\t\t\t</tr>\r\n\t\t\t\t\t\r\n\t\t\t\t\r\n\r\n\t\t\t\t\r\n\t\t\t\r\n\t\t</tbody>\r\n\t</table>\r\n</article>'

# %%
# OTP 생성을 위한 요청
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
for i in range(1, 13):
    month = f'{i:02d}'  # 2자리 숫자 형식으로 변환
    otp_data = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': month,
        'searchCorpName': '회사명/코드',  # 이 부분은 실제 검색어로 교체해야 할 수 있습니다.
        'selYear': '2023',
        'showMonth': month,
        'periodType': 'M',
        'selDate': f'2023-{month}-01', 
        'submitFlagYn': 'N'
    }
    headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}
otp_response = requests.post(otp_url, data=otp_data, headers=headers)

# %%
otp_response.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n<article class="scrarea type-00">\r\n\t<h3 class="ttl type-39">* <strong>2023</strong>년 <strong>12</strong>월 <em>감자 일정</em></h3>\r\n\t<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">\r\n\t\t<caption>목록</caption>\r\n\t\t<colgroup>\r\n\t\t\t<col width="10%" />\r\n\t\t\t<col width="16%" />\r\n\t\t\t<col width="7%" />\r\n\t\t\t<col width="8%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="9%" />\r\n\t\t\t<col width="15%" />\r\n\t\t\t<col width="*%" />\r\n\t\t</colgroup>\r\n\t\t<thead>\r\n\t\t\t<tr class="first">\r\n\t\t\t\t<th rowspan="2" class="first" scope="col">감자<br />기준일</th>\r\n\t\t\t\t<th rowspan="2" scope="col">회사명</th>\r\n\t\t\t\t<th rowspan="2" scope="col">종목코드</th>\r\n\t\t\t\t<th rowspan="2" scope="col">감자비율(%)</th>\r\n\t\t\t\t<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>\r\n\t\t\t\t<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>\r\n\t\t\t\t<th rowspan="2" scope="col">구주권 제출기간</th>\r\n\t\t\t\t<th rowspan="2" scope="col">원문보기</th>\r\n\t\t\t</tr>\r\n\t\t\t<tr>\r\n\t\t\t\t<th class="thc" scope="col">보통주</th>\r\n\t\t\t\t<th class="thc" scope="col">우선주</th>\r\n\t\t\t\t<th class="thc" scope="col">보통주</th>\r\n\t\t\t\t<th class="thc" scope="col">우선주</th>\r\n\t\t\t</tr>\r\n\t\t</thead>\r\n\t\t<tbody>\r\n\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t<tr class="first">\r\n\t\t\t\t\t\t<td class="first txc">2023-12-04</td>\r\n\t\t\t\t\t\t<td><img src=\'/images/common/icn_t_ko.gif\' class=\'vmiddle legend\' alt=\'코스닥\'> <a id="companysum" href="#companysum" onclick="companysummary_open(\'17488\'); return false;" title=\'장원테크\'> 장원테크</a> <img src=\'/images/common/icn_t_kwan.gif\' class=\'vmiddle legend\' alt=\'관리종목\'/> <img src=\'/images/common/icn_t_hwan.gif\' class=\'vmiddle legend\' alt=\'투자주의환기종목\'> </td>\r\n\t\t\t\t\t\t<td class="txc">174880</td>\r\n\t\t\t\t\t\t<td class="txr">                      80.00</td>\r\n\t\t\t\t\t\t<td class="txr">                  21,906,325</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txr">                   4,381,265</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txc"></td>\r\n\t\t\t\t\t\t<td class="txc">\r\n\t\t\t\t\t\t\t<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer(\'20230915000342\',\'\'); return false;"></a>\r\n\t\t\t\t\t\t</td>\r\n\t\t\t\t\t</tr>\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t<tr class="">\r\n\t\t\t\t\t\t<td class="first txc">2023-12-04</td>\r\n\t\t\t\t\t\t<td><img src=\'/images/common/icn_t_yu.gif\' class=\'vmiddle legend\' alt=\'유가증권\'> <a id="companysum" href="#companysum" onclick="companysummary_open(\'00288\'); return false;" title=\'대유에이텍\'> 대유에이텍</a> </td>\r\n\t\t\t\t\t\t<td class="txc">002880</td>\r\n\t\t\t\t\t\t<td class="txr">                      66.67</td>\r\n\t\t\t\t\t\t<td class="txr">                 116,190,505</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txr">                  38,730,168</td>\r\n\t\t\t\t\t\t<td class="txr"></td>\r\n\t\t\t\t\t\t<td class="txc"></td>\r\n\t\t\t\t\t\t<td class="txc">\r\n\t\t\t\t\t\t\t<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer(\'20230921000356\',\'\'); return false;"></a>\r\n\t\t\t\t\t\t</td>\r\n\t\t\t\t\t</tr>\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t<tr class="">\r\n\t\t\t\t\t\t<td class="first txc">2023-12-07</td>\r\n\t\t\t\t\t\t<td><img src=\'/images/common/icn_t_ko.gif\' class=\'vmiddle legend\' alt=\'코스닥\'> <a id="companysum" href="#companysum" onclick="companysummary_open(\'15991\'); return false;" title=\'스킨앤스킨\'> 스킨앤스킨</a> <img src=\'/images/common/icn_t_hwan.gif\' class=\'vmiddle legend\' alt=\'투자주의환기종목\'> </td>\r\n\t\t\t\t\t\t<td class="txc">159910</td>\r\n\t\t\t\t\t\t<td class="txr">  ...

# %%
import requests
from bs4 import BeautifulSoup

# OTP 생성을 위한 요청
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

for i in range(1, 13):
    month = f'{i:02d}'  # 2자리 숫자 형식으로 변환
    otp_data = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': month,
        'searchCorpName': '회사명/코드',  # 이 부분은 실제 검색어로 교체해야 할 수 있습니다.
        'selYear': '2023',
        'showMonth': month,
        'periodType': 'M',
        'selDate': f'2023-{month}-01', 
        'submitFlagYn': 'N'
    }

    otp_response = requests.post(otp_url, data=otp_data, headers=headers)
    soup = BeautifulSoup(otp_response.text, 'html.parser')
    
    # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명과 종목코드를 추출합니다.
    for tr in soup.find_all('tr'):
        tds = tr.find_all('td')
        if len(tds) > 1:  # 'td' 태그가 2개 이상 있는 행을 찾습니다.
            company_name = tds[0].text.strip()  # 첫 번째 'td'에서 텍스트를 가져와 공백을 제거합니다.
            stock_code = tds[1].text.strip()    # 두 번째 'td'에서 텍스트를 가져와 공백을 제거합니다.
            print(f'회사명: {company_name}, 종목코드: {stock_code}')
# Out:
# 회사명: 2023-01-25, 종목코드: 어스앤에어로스페이스
# 회사명: 2023-01-27, 종목코드: 일월지엠엘
# 회사명: 2023-02-15, 종목코드: 비디아이
# 회사명: 2023-02-17, 종목코드: 비디아이
# 회사명: 2023-03-21, 종목코드: 에이프로젠 H&G
# 회사명: 2023-03-29, 종목코드: 상상인인더스트리
# 회사명: 2023-04-11, 종목코드: 비케이홀딩스
# 회사명: 2023-04-13, 종목코드: 리더스 기술투자
# 회사명: 2023-04-17, 종목코드: 디에스앤엘
# 회사명: 2023-04-17, 종목코드: 지티지웰니스
# 회사명: 2023-04-21, 종목코드: 삼성물산
# 회사명: 2023-04-25, 종목코드: 광주신세계
# 회사명: 2023-05-02, 종목코드: 원익피앤이
# 회사명: 2023-05-03, 종목코드: 티와이홀딩스
# 회사명: 2023-05-03, 종목코드: 커넥트웨이브
# 회사명: 2023-05-03, 종목코드: 카카오
# 회사명: 2023-05-08, 종목코드: 엘아이에스
# 회사명: 2023-06-08, 종목코드: 시티랩스
# 회사명: 2023-07-03, 종목코드: 케이바이오
# 회사명: 2023-07-20, 종목코드: 세원이앤씨
# 회사명: 2023-07-25, 종목코드: KH 전자
# 회사명: 2023-08-01, 종목코드: 동원산업
# 회사명: 2023-08-01, 종목코드: KG케미칼
# 회사명: 2023-08-03, 종목코드: 크레버스
# 회사명: 2023-08-22, 종목코드: 세종텔레콤
# 회사명: 2023-08-23, 종목코드: 아이에이치큐
# 회사명: 2023-09-06, 종목코드: KH 필룩스
# 회사명: 2023-09-23, 종목코드: 인바이오젠
# 회사명: 2023-09-26, 종목코드: 녹원씨엔아이
# 회사명: 2023-10-10, 종목코드: 한창
# 회사명: 2023-10-18, 종목코드: 락앤락
# 회사명: 2023-10-24, 종목코드: 베스파
# 회사명: 2023-10-26, 종목코드: 베스파
# 회사명: 2023-10-30, 종목코드: 로보쓰리에이아이앤로보틱스
# 회사명: 2023-11-01, 종목코드: 바다로19호
# 회사명: 2023-11-17, 종목코드: 엔터파트너즈
# 회사명: 2023-11-24, 종목코드: 피에이치씨
# 회사명: 2023-12-04, 종목코드: 장원테크
# 회사명: 2023-12-04, 종목코드: 대유에이텍
# 회사명: 2023-12-07, 종목코드: 스킨앤스킨
# 회사명: 2023-12-11, 종목코드: 아이오케이
# 회사명: 2023-12-11, 종목코드: 아이에이치큐
# 회사명: 2023-12-12, 종목코드: 현대지에프홀딩스
# 회사명: 2023-12-26, 종목코드: 웰킵스하이텍

# %%
import requests
from bs4 import BeautifulSoup
import re

# OTP 생성을 위한 요청
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

for i in range(1, 13):
    month = f'{i:02d}'  # 2자리 숫자 형식으로 변환
    otp_data = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': month,
        'searchCorpName': '',  # 실제 검색어가 필요하지 않은 경우 빈 문자열을 사용할 수 있습니다.
        'selYear': '2023',
        'showMonth': month,
        'periodType': 'M',
        'selDate': f'2023-{month}-01',
        'submitFlagYn': 'N'
    }

    otp_response = requests.post(otp_url, data=otp_data, headers=headers)
    soup = BeautifulSoup(otp_response.text, 'html.parser')
    
    # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명과 종목코드를 추출합니다.
    for tr in soup.find_all('tr'):
        # 종목코드는 6자리 숫자로 되어 있습니다.
        stock_code_search = re.search(r'\b\d{6}\b', tr.text)
        if stock_code_search:
            stock_code = stock_code_search.group()
            company_name_search = re.search(r'[가-힣]+', tr.text)
            if company_name_search:
                company_name = company_name_search.group()
                print(f'회사명: {company_name}, 종목코드: {stock_code}')
# Out:
# 회사명: 어스앤에어로스페이스, 종목코드: 263540
# 회사명: 일월지엠엘, 종목코드: 178780
# 회사명: 비디아이, 종목코드: 148140
# 회사명: 비디아이, 종목코드: 148140
# 회사명: 에이프로젠, 종목코드: 109960
# 회사명: 상상인인더스트리, 종목코드: 101000
# 회사명: 비케이홀딩스, 종목코드: 050090
# 회사명: 리더스, 종목코드: 019570
# 회사명: 디에스앤엘, 종목코드: 141020
# 회사명: 지티지웰니스, 종목코드: 219750
# 회사명: 삼성물산, 종목코드: 028260
# 회사명: 광주신세계, 종목코드: 037710
# 회사명: 원익피앤이, 종목코드: 217820
# 회사명: 티와이홀딩스, 종목코드: 363280
# 회사명: 커넥트웨이브, 종목코드: 119860
# 회사명: 카카오, 종목코드: 035720
# 회사명: 엘아이에스, 종목코드: 138690
# 회사명: 시티랩스, 종목코드: 139050
# 회사명: 케이바이오, 종목코드: 038530
# 회사명: 세원이앤씨, 종목코드: 091090
# 회사명: 전자, 종목코드: 111870
# 회사명: 동원산업, 종목코드: 006040
# 회사명: 케미칼, 종목코드: 001390
# 회사명: 크레버스, 종목코드: 096240
# 회사명: 세종텔레콤, 종목코드: 036630
# 회사명: 아이에이치큐, 종목코드: 003560
# 회사명: 필룩스, 종목코드: 033180
# 회사명: 인바이오젠, 종목코드: 101140
# 회사명: 녹원씨엔아이, 종목코드: 065560
# 회사명: 한창, 종목코드: 005110
# 회사명: 락앤락, 종목코드: 115390
# 회사명: 베스파, 종목코드: 299910
# 회사명: 베스파, 종목코드: 299910
# 회사명: 로보쓰리에이아이앤로보틱스, 종목코드: 238500
# 회사명: 바다로, 종목코드: 155900
# 회사명: 엔터파트너즈, 종목코드: 058450
# 회사명: 피에이치씨, 종목코드: 057880
# 회사명: 장원테크, 종목코드: 174880
# 회사명: 대유에이텍, 종목코드: 002880
# 회사명: 스킨앤스킨, 종목코드: 159910
# 회사명: 아이오케이, 종목코드: 078860
# 회사명: 아이에이치큐, 종목코드: 003560
# 회사명: 현대지에프홀딩스, 종목코드: 005440
# 회사명: 웰킵스하이텍, 종목코드: 043590

# %%
import requests

# OTP 생성을 위한 요청 URL
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'

# 연도별로 반복
for year in range(2010, 2024):
    # 월별로 반복
    for month in range(1, 13):
        month_str = f'{month:02d}'  # 2자리 숫자 형식으로 변환
        # 요청할 데이터
        otp_data = {
            'method': 'searchReductionCapital',
            'forward': 'searchreductioncapital',
            'selMonth': month_str,
            'searchCorpName': '',  # 검색어가 필요하지 않으면 빈 문자열로 설정
            'selYear': str(year),
            'showMonth': month_str,
            'periodType': 'M',
            'selDate': f'{year}-{month_str}-01',
            'submitFlagYn': 'N'
        }
        # 헤더 설정
        headers = {
            'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
            # 필요한 경우 추가 헤더를 추가합니다.
        }
        
        # POST 요청 보내기
        otp_response = requests.post(otp_url, data=otp_data, headers=headers)
        
        # 응답 처리 (여기에서는 응답 내용을 출력만 합니다. 실제로는 데이터 추출 등의 처리가 필요합니다.)
        print(otp_response.text)

        # 잠시 대기하는 것이 좋을 수 있습니다 (서버 부하 방지를 위해)
        time.sleep(1)  # 필요한 경우 주석을 해제하고 사용
# Out:
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>01</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-01-17</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('00362'); return false;" title='KG모빌리티'> KG모빌리티</a> </td>
# 						<td class="txc">003620</td>
# 						<td class="txr">                      66.68</td>
# 						<td class="txr">                 108,410,431</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  36,120,556</td>
# 						<td class="txr"></td>
# 						<td class="txc">-</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100127000126',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>02</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-02-03</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('04782'); return false;" title='초록뱀미디어'> 초록뱀미디어</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> </td>
# 						<td class="txc">047820</td>
# 						<td class="txr">                      50.00</td>
# 						<td class="txr">                  72,748,512</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  36,374,256</td>
# 						<td class="txr"></td>
# 						<td class="txc">2009.12.31~2010.02.03</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20091230000445',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>03</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-03-27</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('03609'); return false;" title='위지트'> 위지트</a> </td>
# 						<td class="txc">036090</td>
# 						<td class="txr">                      66.67</td>
# 						<td class="txr">                  17,940,005</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   5,980,001</td>
# 						<td class="txr"></td>
# 						<td class="txc">2010년 2월 27일~2010년 3월 27일</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100917000412',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2010-03-28</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('08979'); return false;" title='제이티'> 제이티</a> </td>
# 						<td class="txc">089790</td>
# 						<td class="txr">                      66.67</td>
# 						<td class="txr">                   7,025,283</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   2,341,761</td>
# 						<td class="txr"></td>
# 						<td class="txc">2010년 02월 26일 ~ 2010년 03월 28일</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100126000460',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>04</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-04-14</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('00068'); return false;" title='LS네트웍스'> LS네트웍스</a> </td>
# 						<td class="txc">000680</td>
# 						<td class="txr">                       9.27</td>
# 						<td class="txr">                  78,838,953</td>
# 						<td class="txr">                      16,846</td>
# 						<td class="txr">                  71,527,542</td>
# 						<td class="txr"></td>
# 						<td class="txc">2010년 03월 14일 ~ 2010년 04월 14일</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100129000516',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2010-04-26</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('08879'); return false;" title='진도'> 진도</a> </td>
# 						<td class="txc">088790</td>
# 						<td class="txr">                      90.00</td>
# 						<td class="txr">                 100,243,190</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  10,024,319</td>
# 						<td class="txr"></td>
# 						<td class="txc">2010년 3월 24일 부터 2010년 4월 26일까지</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100510000097',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>05</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-05-04</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('02222'); return false;" title='TKG애강'> TKG애강</a> </td>
# 						<td class="txc">022220</td>
# 						<td class="txr">                       9.31</td>
# 						<td class="txr">                  32,233,340</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  29,233,340</td>
# 						<td class="txr"></td>
# 						<td class="txc">-</td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20100309000410',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2010</strong>년 <strong>06</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2010-06-04</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('05418'); return false;" title='메디콕스'> 메디콕스</a> </td>
# 						<td class="txc">054180</td>
# 						<td class="txr">                      90.00</td>
# 						<td class="txr">
td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('05788'); return false;" title='피에이치씨'> 피에이치씨</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> <img src='/images/common/icn_t_hwan.gif' class='vmiddle legend' alt='투자주의환기종목'> </td>
# 						<td class="txc">057880</td>
# 						<td class="txr">                      93.33</td>
# 						<td class="txr">                 118,807,375</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   7,920,491</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20231012000193',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
#
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2023</strong>년 <strong>12</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2023-12-04</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('17488'); return false;" title='장원테크'> 장원테크</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> <img src='/images/common/icn_t_hwan.gif' class='vmiddle legend' alt='투자주의환기종목'> </td>
# 						<td class="txc">174880</td>
# 						<td class="txr">                      80.00</td>
# 						<td class="txr">                  21,906,325</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   4,381,265</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20230915000342',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-04</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('00288'); return false;" title='대유에이텍'> 대유에이텍</a> </td>
# 						<td class="txc">002880</td>
# 						<td class="txr">                      66.67</td>
# 						<td class="txr">                 116,190,505</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  38,730,168</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20230921000356',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-07</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('15991'); return false;" title='스킨앤스킨'> 스킨앤스킨</a> <img src='/images/common/icn_t_hwan.gif' class='vmiddle legend' alt='투자주의환기종목'> </td>
# 						<td class="txc">159910</td>
# 						<td class="txr">                      90.00</td>
# 						<td class="txr">                 354,150,749</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  35,415,074</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20230915000619',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-11</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('07886'); return false;" title='아이오케이'> 아이오케이</a> </td>
# 						<td class="txc">078860</td>
# 						<td class="txr">                      95.00</td>
# 						<td class="txr">                  96,126,472</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   4,806,323</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20231016000483',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-11</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('00356'); return false;" title='아이에이치큐'> 아이에이치큐</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> </td>
# 						<td class="txc">003560</td>
# 						<td class="txr">                      66.67</td>
# 						<td class="txr">                  16,153,043</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   5,384,347</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20231031000588',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-12</td>
# 						<td><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('00544'); return false;" title='현대지에프홀딩스'> 현대지에프홀딩스</a> </td>
# 						<td class="txc">005440</td>
# 						<td class="txr">                       2.90</td>
# 						<td class="txr">                 162,399,732</td>
# 						<td class="txr">                           0</td>
# 						<td class="txr">                 157,691,867</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20230911000138',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-12-26</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('04359'); return false;" title='웰킵스하이텍'> 웰킵스하이텍</a> </td>
# 						<td class="txc">043590</td>
# 						<td class="txr">                      25.00</td>
# 						<td class="txr">                  36,161,850</td>
# 						<td class="txr"></td>
# 						<td class="txr">                  27,121,388</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20231101000375',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

# OTP 생성을 위한 요청 URL
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

# 연도별로 반복
for year in range(2010, 2024):
    # 월별로 반복
    for month in range(1, 13):
        month_str = f'{month:02d}'  # 2자리 숫자 형식으로 변환
        otp_data = {
            'method': 'searchReductionCapital',
            'forward': 'searchreductioncapital',
            'selMonth': month_str,
            'searchCorpName': '',
            'selYear': str(year),
            'showMonth': month_str,
            'periodType': 'M',
            'selDate': f'{year}-{month_str}-01',
            'submitFlagYn': 'N'
        }

        # POST 요청 보내기
        otp_response = requests.post(otp_url, data=otp_data, headers=headers)
        soup = BeautifulSoup(otp_response.text, 'html.parser')
        
        # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명과 종목코드를 추출합니다.
        for tr in soup.find_all('tr'):
            # 종목코드는 6자리 숫자로 되어 있습니다.
            stock_code_search = re.search(r'\b\d{6}\b', tr.text)
            if stock_code_search:
                stock_code = stock_code_search.group()
                company_name_search = re.search(r'[가-힣]+', tr.text)
                if company_name_search:
                    company_name = company_name_search.group()
                    print(f'회사명: {company_name}, 종목코드: {stock_code}')

        # 잠시 대기하는 것이 좋을 수 있습니다 (서버 부하 방지를 위해)
        time.sleep(0.1)  # 필요한 경우 주석을 해제하고 사용

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

# OTP 생성을 위한 요청 URL
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

# 연도별로 반복
for year in range(2010, 2024):
    # 월별로 반복
    for month in range(1, 13):
        month_str = f'{month:02d}'  # 2자리 숫자 형식으로 변환
        otp_data = {
            'method': 'searchReductionCapital',
            'forward': 'searchreductioncapital',
            'selMonth': month_str,
            'searchCorpName': '',
            'selYear': str(year),
            'showMonth': month_str,
            'periodType': 'M',
            'selDate': f'{year}-{month_str}-01',
            'submitFlagYn': 'N'
        }

        # POST 요청 보내기
        otp_response = requests.post(otp_url, data=otp_data, headers=headers)
        soup = BeautifulSoup(otp_response.text, 'html.parser')
        
        # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명과 종목코드를 추출합니다.
        for tr in soup.find_all('tr'):
            # 종목코드는 6자리 숫자로 되어 있습니다.
            stock_code_search = re.search(r'\b\d{6}\b', tr.text)
            if stock_code_search:
                stock_code = stock_code_search.group()
                company_name_search = re.search(r'[가-힣]+', tr.text)
                if company_name_search:
                    company_name = company_name_search.group()
                    print(f'회사명: {company_name}, 종목코드: {stock_code}')

        # 잠시 대기하는 것이 좋을 수 있습니다 (서버 부하 방지를 위해)
        time.sleep(0.1)  # 필요한 경우 주석을 해제하고 사용
# Out:
# 회사명: 모빌리티, 종목코드: 003620
# 회사명: 초록뱀미디어, 종목코드: 047820
# 회사명: 위지트, 종목코드: 036090
# 회사명: 제이티, 종목코드: 089790
# 회사명: 네트웍스, 종목코드: 000680
# 회사명: 진도, 종목코드: 088790
# 회사명: 애강, 종목코드: 022220
# 회사명: 메디콕스, 종목코드: 054180
# 회사명: 삼보모터스, 종목코드: 053700
# 회사명: 년, 종목코드: 060900
# 회사명: 초록뱀미디어, 종목코드: 047820
# 회사명: 우원개발, 종목코드: 046940
# 회사명: 케이씨피드, 종목코드: 025880
# 회사명: 컨버즈, 종목코드: 109070
# 회사명: 셀트리온, 종목코드: 068270
# 회사명: 바이오스마트, 종목코드: 038460
# 회사명: 더라미, 종목코드: 032860
# 회사명: 메탈, 종목코드: 024840
# 회사명: 금호타이어, 종목코드: 073240
# 회사명: 년, 종목코드: 044180
# 회사명: 소니드, 종목코드: 060230
# 회사명: 바이온, 종목코드: 032980
# 회사명: 금호건설, 종목코드: 002990
# 회사명: 티웨이홀딩스, 종목코드: 004870
# 회사명: 한성크린텍, 종목코드: 066980
# 회사명: 바른손, 종목코드: 018700
# 회사명: 재영솔루텍, 종목코드: 049630
# 회사명: 동양, 종목코드: 001520
# 회사명: 인바이오젠, 종목코드: 101140
# 회사명: 인바이오젠, 종목코드: 101140
# 회사명: 디모아, 종목코드: 016670
# 회사명: 세종텔레콤, 종목코드: 036630
# 회사명: 라온시큐어, 종목코드: 042510
# 회사명: 아이오케이, 종목코드: 078860
# 회사명: 서울리거, 종목코드: 043710
# 회사명: 팬스타엔터프라이즈, 종목코드: 054300
# 회사명: 알톤스포츠, 종목코드: 123750
# 회사명: 대한해운, 종목코드: 005880
# 회사명: 웰바이오텍, 종목코드: 010600
# 회사명: 유니켐, 종목코드: 011330
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

# 연도별로 반복
for year in range(2010, 2024):
    # 월별로 반복
    for month in range(1, 13):
        month_str = f'{month:02d}'  # 2자리 숫자 형식으로 변환
        otp_data = {
            'method': 'searchReductionCapital',
            'forward': 'searchreductioncapital',
            'selMonth': month_str,
            'searchCorpName': '',
            'selYear': str(year),
            'showMonth': month_str,
            'periodType': 'M',
            'selDate': f'{year}-{month_str}-01',
            'submitFlagYn': 'N'
        }

        # POST 요청 보내기
        otp_response = requests.post(otp_url, data=otp_data, headers=headers)
        soup = BeautifulSoup(otp_response.text, 'html.parser')
        
        # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명과 종목코드를 추출합니다.
        for tr in soup.find_all('tr'):
            # 종목코드는 6자리 숫자로 되어 있습니다.
            stock_code_search = re.search(r'\b\d{6}\b', tr.text)
            if stock_code_search:
                stock_code = stock_code_search.group()
                company_name_search = re.search(r'[\w가-힣]+(?:\s[\w가-힣]+)*', tds[2].text)                
                if company_name_search:
                    company_name = company_name_search.group()
                    print(f'회사명: {company_name}, 종목코드: {stock_code}')

        # 잠시 대기하는 것이 좋을 수 있습니다 (서버 부하 방지를 위해)
        time.sleep(0.1)  # 필요한 경우 주석을 해제하고 사용
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10300\4160156370.py in <module>
#      38             if stock_code_search:
#      39                 stock_code = stock_code_search.group()
# ---> 40                 company_name_search = re.search(r'[\w가-힣]+(?:\s[\w가-힣]+)*', tds[2].text)
#      41                 if company_name_search:
#      42                     company_name = company_name_search.group()
#
# NameError: name 'tds' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

# OTP 생성을 위한 요청 URL
otp_url = 'https://kind.krx.co.kr/common/stockschedule.do'
headers = {
    'Referer': 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11',
    # 필요한 경우 추가 헤더를 추가합니다.
}

# 연도별로 반복
for year in range(2010, 2024):
    # 월별로 반복
    for month in range(1, 13):
        month_str = f'{month:02d}'  # 2자리 숫자 형식으로 변환
        otp_data = {
            'method': 'searchReductionCapital',
            'forward': 'searchreductioncapital',
            'selMonth': month_str,
            'searchCorpName': '',
            'selYear': str(year),
            'showMonth': month_str,
            'periodType': 'M',
            'selDate': f'{year}-{month_str}-01',
            'submitFlagYn': 'N'
        }

        # POST 요청 보내기
        otp_response = requests.post(otp_url, data=otp_data, headers=headers)
        soup = BeautifulSoup(otp_response.text, 'html.parser')
        
        # 'tr' 태그를 찾고 그 내부에서 'td' 태그를 찾아 회사명, 종목코드, 감자 기준일을 추출합니다.
        for tr in soup.find_all('tr'):
            tds = tr.find_all('td')
            if tds and len(tds) >= 3:  # 'td' 태그가 존재하며 최소한 3개 이상의 'td' 태그가 있는지 확인합니다.
                reduction_base_date = tds[0].text.strip()  # 첫 번째 'td'의 텍스트를 감자 기준일로 사용합니다.
                stock_code_search = re.search(r'\b\d{6}\b', tds[1].text)
                if stock_code_search:
                    stock_code = stock_code_search.group()
                    # 회사명을 추출하기 위한 정규 표현식에서 한글 뿐만 아니라 영문자와 숫자도 포함되도록 수정합니다.
                    company_name_search = re.search(r'[가-힣]+', tr.text)
                    if company_name_search:
                        company_name = company_name_search.group()
                        print(f'회사명: {company_name}, 종목코드: {stock_code}, 감자 기준일: {reduction_base_date}')

        # 잠시 대기하는 것이 좋을 수 있습니다 (서버 부하 방지를 위해)
        time.sleep(0.1)  # 필요한 경우 주석을 해제하고 사용

# %%
if otp_response.ok:
    otp = otp_response.text
    print("OTP:", otp)
    

    # 파일 다운로드를 위한 요청
    download_url = 'DOWNLOAD_FILE_URL'
    download_data = {
        'code': otp,  # OTP를 파라미터로 사용합니다.
    }
    download_response = requests.post(download_url, data=download_data, headers=headers)
    
    if download_response.ok:
        # 파일 내용 처리
        file_content = BytesIO(download_response.content)
        df = pd.read_csv(file_content)
        print(df.head())
    else:
        print(f'Error {download_response.status_code}: Failed to download file')
else:
    print(f'Error {otp_response.status_code}: Failed to generate OTP')
# Out:
# OTP:
#
#
#
#
# <article class="scrarea type-00">
# 	<h3 class="ttl type-39">* <strong>2023</strong>년 <strong>01</strong>월 <em>감자 일정</em></h3>
# 	<table class="list type-99 mt17" summary="감자기준일, 회사명, 종목코드, 감자비율(%), 감자 전 발행주식수 보통주, 감자 전 발행주식수 우선주, 감자 후 발행주식수 보통주, 감자 후 발행주식수 우선주, 구주권 제출기간, 원문보기">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="10%" />
# 			<col width="16%" />
# 			<col width="7%" />
# 			<col width="8%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="9%" />
# 			<col width="15%" />
# 			<col width="*%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first">
# 				<th rowspan="2" class="first" scope="col">감자<br />기준일</th>
# 				<th rowspan="2" scope="col">회사명</th>
# 				<th rowspan="2" scope="col">종목코드</th>
# 				<th rowspan="2" scope="col">감자비율(%)</th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 전 발행주식수 </th>
# 				<th class="th_group" colspan="2" scope="colgroup">감자 후 발행주식수 </th>
# 				<th rowspan="2" scope="col">구주권 제출기간</th>
# 				<th rowspan="2" scope="col">원문보기</th>
# 			</tr>
# 			<tr>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 				<th class="thc" scope="col">보통주</th>
# 				<th class="thc" scope="col">우선주</th>
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
#
#
#
#
# 					<tr class="first">
# 						<td class="first txc">2023-01-25</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('26354'); return false;" title='어스앤에어로스페이스'> 어스앤에어로스페이스</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> <img src='/images/common/icn_t_hwan.gif' class='vmiddle legend' alt='투자주의환기종목'> </td>
# 						<td class="txc">263540</td>
# 						<td class="txr">                      80.00</td>
# 						<td class="txr">                   7,733,747</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   2,102,547</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20221215001394',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
# 					<tr class="">
# 						<td class="first txc">2023-01-27</td>
# 						<td><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('17878'); return false;" title='일월지엠엘'> 일월지엠엘</a> <img src='/images/common/icn_t_kwan.gif' class='vmiddle legend' alt='관리종목'/> <img src='/images/common/icn_t_hwan.gif' class='vmiddle legend' alt='투자주의환기종목'> </td>
# 						<td class="txc">178780</td>
# 						<td class="txr">                      80.00</td>
# 						<td class="txr">                  34,820,984</td>
# 						<td class="txr"></td>
# 						<td class="txr">                   6,964,196</td>
# 						<td class="txr"></td>
# 						<td class="txc"></td>
# 						<td class="txc">
# 							<a href="#DocuView" title="원문보기" class="btn ico doc-view" onclick="openDisclsViewer('20230217000855',''); return false;"></a>
# 						</td>
# 					</tr>
#
#
#
#
#
# 		</tbody>
# 	</table>
# </article>
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10380\958384195.py in <module>
#       9         'code': otp,  # OTP를 파라미터로 사용합니다.
#      10     }
# ---> 11     download_response = requests.post(download_url, data=download_data, headers=headers)
#      12
#      13     if download_response.ok:
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     573             hooks=hooks,
#     574         )
# --> 575         prep = self.prepare_request(req)
#     576
#     577         proxies = proxies or {}
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in prepare_request(self, request)
#     484
#     485         p = PreparedRequest()
# --> 486         p.prepare(
#     487             method=request.method.upper(),
#     488             url=request.url,
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366
#     367         self.prepare_method(method)
# --> 368         self.prepare_url(url, params)
#     369         self.prepare_headers(headers)
#     370         self.prepare_cookies(cookies)
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\models.py in prepare_url(self, url, params)
#     437
#     438         if not scheme:
# --> 439             raise MissingSchema(
#     440                 f"Invalid URL {url!r}: No scheme supplied. "
#     441                 f"Perhaps you meant https://{url}?"
#
# MissingSchema: Invalid URL 'DOWNLOAD_FILE_URL': No scheme supplied. Perhaps you meant https://DOWNLOAD_FILE_URL?

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://kind.krx.co.kr/common/stockschedule.do?method=StockScheduleMain&index=11#'

for i in range(1, 13):
    month = f'{i:02d}'  # 2자리 숫자 형식으로 변환
    payload = {
        'method': 'searchReductionCapital',
        'forward': 'searchreductioncapital',
        'selMonth': month,
        'searchCorpName': '회사명/코드',  # 이 부분은 실제 검색어로 교체해야 할 수 있습니다.
        'selYear': '2023',
        'showMonth': month,
        'periodType': 'M',
        'selDate': f'2023-{month}-01', 
        'submitFlagYn': 'N'
    }

    response = rq.post(url, data=payload)
    
    if response.ok:
        html = BeautifulSoup(response.content, 'html.parser')
        print(html.prettify())
    else:
        print(f'Error {response.status_code}: Failed to retrieve data for month {month}')
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="kr" http-equiv="content-language"/>
#   <meta content="text/css" http-equiv="content-style-type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="no" http-equiv="imagetoolbar"/>
#   <meta content="(c)2012" name="copyright"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="description"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="keywords"/>
#   <title>
#    대한민국 대표 기업공시채널 KIND
#   </title>
#   <link href="../js/jquery/themes-base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/default_new.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/common.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/popup.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
#   <script src="../js/trans.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="../js/common.js" type="text/javascript">
#   </script>
#   <script src="../js/common-pop.js?version=20220624" type="text/javascript">
#   </script>
#   <script src="../js/common-ajax.js" type="text/javascript">
#   </script>
#   <script src="../js/JCommon.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="pop">
#   <header class="popup">
#    <h1 class="ttl type-99" id="title">
#     증시일정
#    </h1>
#   </header>
#   <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
#    <input id="method" name="method" type="hidden"/>
#    <input id="forward" name="forward" type="hidden"/>
#    <input id="searchCodeType" name="searchCodeType" type="hidden"/>
#    <!--number:법인코드 char:법인명-->
#    <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden"/>
#    <!--법인코드-->
#    <input id="menuIndex" name="menuIndex" type="hidden"/>
#    <!--검색할 페이지-->
#    <input id="selMonth" name="selMonth" type="hidden"/>
#    <!--월-->
#    <input id="selDay" name="selDay" type="hidden"/>
#    <!--일자-->
#    <input id="enterFlag" name="enterFlag" type="hidden"/>
#    <input id="searchMenu" name="searchMenu" type="hidden" value="01"/>
#    <input id="nowYear" name="nowYear" type="hidden" value="2023"/>
#    <input id="nowMonth" name="nowMonth" type="hidden" value="11"/>
#    <!-- 리스트검색 -->
#    <section class="contents popup">
#     <section class="roundbox type-99">
#      <div class="form-search type-99">
#       <table summary="검색">
#        <caption>
#         증시일정
#        </caption>
#        <colgroup>
#         <col width="50"/>
#         <col width="200"/>
#         <col width="90"/>
#         <col width="*"/>
#        </colgroup>
#        <tbody>
#         <tr class="first">
#          <th scope="row">
#           <label for="name">
#            회사명
#           </label>
#          </th>
#          <td>
#           <input class="middle" id="searchCorpName" name="searchCorpName" onclick="fnTextInit(); return false;" type="text"/>
#           <a href="#searchCorp" onclick="findCompanyName();return false;" title="회사명찾기">
#            <img alt="회사명찾기" class="vtop" id="searchCorp" src="../../images/common/btn_zoom.gif"/>
#           </a>
#          </td>
#          <td>
#           <select class="select" id="selYear" name="selYear" onchange="fnYearChange()">
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option selected="selected" value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#            <option value="2025">
#             2025
#            </option>
#           </select>
#           년
#           <select class="select" id="showMonth" name="showMonth" style="display:none">
#            <option value="1">
#             1
#            </option>
#            <option value="2">
#             2
#            </option>
#            <option value="3">
#             3
#            </option>
#            <option value="4">
#             4
#            </option>
#            <option value="5">
#             5
#            </option>
#            <option value="6">
#             6
#            </option>
#            <option value="7">
#             7
#            </option>
#            <option value="8">
#             8
#            </option>
#            <option value="9">
#             9
#            </option>
#            <option value="10">
#             10
#            </option>
#            <option selected="selected" value="11">
#             11
#            </option>
#            <option value="12">
#             12
#            </option>
#           </select>
#          </td>
#          <td>
#           <ul class="btn-set months">
#            <li>
#             <a class="ord-00" href="#" id="january" onclick="fnSwapImage('1', 'click')" title="1월">
#              <span>
#               1월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-01" href="#" id="february" onclick="fnSwapImage('2', 'click')" title="2월">
#              <span>
#               2월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-02" href="#" id="march" onclick="fnSwapImage('3', 'click')" title="3월">
#              <span>
#               3월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-03" href="#" id="april" onclick="fnSwapImage('4', 'click')" title="4월">
#              <span>
#               4월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-04" href="#" id="may" onclick="fnSwapImage('5', 'click')" title="5월">
#              <span>
#               5월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-05" href="#" id="june" onclick="fnSwapImage('6', 'click')" title="6월">
#              <span>
#               6월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-06" href="#" id="july" onclick="fnSwapImage('7', 'click')" title="7월">
#              <span>
#               7월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-07" href="#" id="august" onclick="fnSwapImage('8', 'click')" title="8월">
#              <span>
#               8월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-08" href="#" id="september" onclick="fnSwapImage('9', 'click')" title="9월">
#              <span>
#               9월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-09" href="#" id="october" onclick="fnSwapImage('10', 'click')" title="10월">
#              <span>
#               10월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-10" href="#" id="november" onclick="fnSwapImage('11', 'click')" title="11월">
#              <span>
#               11월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-11" href="#" id="december" onclick="fnSwapImage('12', 'click')" title="12월">
#              <span>
#               12월
#              </span>
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#      <img alt="" class="tl" src="../images/common/rbox-type-99-tl.png"/>
#      <img alt="" class="bl" src="../images/common/rbox-type-99-bl.png"/>
#      <img alt="" class="tr" src="../images/common/rbox-type-99-tr.png"/>
#      <img alt="" class="br" src="../images/common/rbox-type-99-br.png"/>
#      <div class="tm">
#      </div>
#      <div class="lm">
#      </div>
#      <div class="bm">
#      </div>
#      <div class="rm">
#      </div>
#     </section>
#     <nav class="tabgroup type-97 mt10">
#      <ul>
#       <li id="A">
#        <a href="#" onclick="fnSearchInit('01'); fnClassActive('01'); return false;" title="종합">
#         <span>
#          종합
#         </span>
#        </a>
#       </li>
#       <li id="B">
#        |
#        <a href="#" onclick="fnSearchInit('02'); fnClassActive('02'); return false;" title="유상종자">
#         <span>
#          유상증자
#         </span>
#        </a>
#       </li>
#       <li id="C">
#        |
#        <a href="#" onclick="fnSearchInit('03'); fnClassActive('03'); return false;" title="무상종자">
#         <span>
#          무상증자
#         </span>
#        </a>
#       </li>
#       <li id="D">
#        |
#        <a href="#" onclick="fnSearchInit('04'); fnClassActive('04'); return false;" title="액면변경">
#         <span>
#          액면변경
#         </span>
#        </a>
#       </li>
#       <li id="E">
#        |
#        <a href="#" onclick="fnSearchInit('05'); fnClassActive('05'); return false;" title="주식배당">
#         <span>
#          주식배당
#         </span>
#        </a>
#       </li>
#       <li id="F">
#        |
#        <a href="#" onclick="fnSearchInit('06'); fnClassActive('06'); return false;" title="감자">
#         <span>
#          감자
#         </span>
#        </a>
#       </li>
#       <li id="G">
#        |
#        <a href="#" onclick="fnSearchInit('07'); fnClassActive('07'); return false;" title="분할/합병">
#         <span>
#          분할/합병
#         </span>
#        </a>
#       </li>
#       <li id="H">
#        |
#        <a href="#" onclick="fnSearchInit('08'); fnClassActive('08'); return false;" title="상호변경">
#         <span>
#          상호변경
#         </span>
#        </a>
#       </li>
#       <li id="I">
#        |
#        <a href="#" onclick="fnSearchInit('09'); fnClassActive('09'); return false;" title="결산실적공시 예정">
#         <span>
#          결산실적공시 예정
#         </span>
#        </a>
#       </li>
#       <li id="J">
#        |
#        <a href="#" onclick="fnSearchInit('10'); fnClassActive('10'); return false;" title="주주총회">
#         <span>
#          주주총회
#         </span>
#        </a>
#       </li>
#       <li id="K">
#        |
#        <a href="#" onclick="fnSearchInit('11'); fnClassActive('11'); return false;" title="감사보고서 제출 현황">
#         <span>
#          감사보고서 제출 현황
#         </span>
#        </a>
#       </li>
#       <li id="L">
#        |
#        <a href="#" onclick="fnSearchInit('12'); fnClassActive('12'); return false;" title="불성실공시법인지정">
#         <span>
#          불성실공시법인지정
#         </span>
#        </a>
#       </li>
#       <li id="M">
#        |
#        <a href="#" onclick="fnSearchInit('13'); fnClassActive('13'); return false;" title="트레이딩캘린더">
#         <span>
#          트레이딩캘린더
#         </span>
#        </a>
#       </li>
#      </ul>
#      <div class="clear">
#      </div>
#     </nav>
#     <div id="search" style="display:none">
#      <section class="roundbox type-99">
#       <div class="form-search type-99">
#        <table summary="기간,시장구분,제출구분">
#         <caption>
#          감사보고서 제출 현황 검색
#         </caption>
#         <colgroup>
#          <col width="70"/>
#          <col width="*"/>
#          <col width="70"/>
#          <col width="*"/>
#         </colgroup>
#         <tbody>
#          <tr class="first">
#           <th scope="row">
#            <label for="selDate">
#             기간
#            </label>
#           </th>
#           <td colspan="3">
#            <input checked="checked" class="rad-00" id="periodType1" name="periodType" type="radio" value="M"/>
#            <label for="periodType1">
#             월간
#            </label>
#            <input class="rad-00" id="periodType2" name="periodType" type="radio" value="D"/>
#            <label for="periodType2">
#             일간
#            </label>
#            <input class="txt input-calendar" id="selDate" name="selDate" onfocus="cal_offMask('document.searchForm.selDate'); focusPeriodType(); return false;" onkeyup="chkLmtDate();return false;" title="기간선택 첫번째" type="text" value=""/>
#           </td>
#          </tr>
#          <tr>
#           <th scope="row">
#            <label for="ldMktTpCd1" id="marketType_div">
#             시장구분
#            </label>
#           </th>
#           <td>
#            <input checked="checked" class="rad-00" id="ldMktTpCd1" name="ldMktTpCd" type="radio" value=""/>
#            <label for="ldMktTpCd1">
#             전체
#            </label>
#            <input class="rad-00" id="ldMktTpCd2" name="ldMktTpCd" type="radio" value="1"/>
#            <label for="ldMktTpCd2">
#             유가증권
#            </label>
#            <input class="rad-00" id="ldMktTpCd3" name="ldMktTpCd" type="radio" value="2"/>
#            <label for="ldMktTpCd3">
#             코스닥
#            </label>
#            <input class="rad-00" id="ldMktTpCd4" name="ldMktTpCd" type="radio" value="6"/>
#            <label for="ldMktTpCd3">
#             코넥스
#            </label>
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("01" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('01');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# 		case "10" : method = "searchGeneralMeetingStockholders"; forward ="searchgeneralmeetingstockholders";	//주주총회
# 					break;
# 		case "11" : method = "searchAuditReportReleaseState"; forward ="searchauditreportreleasestate";			//감사보고서 제출 현황
# 					break;
# 		case "12" : method = "searchInsincerityDistribute"; forward ="searchinsinceritydistribute";				//불성실공시법인지정
# 					break;
# 		case "13" : method = "searchTraidingCalendar"; forward ="searchtraidingcalendar";						//트레이딩캘린더
# 					break;
# 	}
#
# 	$('#searchForm > #searchMenu').val(no);
# 	$("#searchForm > #method").val(method);
# 	$("#searchForm > #forward").val(forward);
#
# 	searchForm.ajaxSubmit({
# 		  ajaxUrl : '/common/stockschedule.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnClassActive(no) {
# 	var searchForm = $('#searchForm');
# 	fnClassDelete();
# 	switch(no){
# 		case "01" : searchForm.find('li[id=A]').attr('class', 'first active')
# 					break;
# 		case "02" : searchForm.find('li[id=B]').attr('class', 'active')
# 					break;
# 		case "03" : searchForm.find('li[id=C]').attr('class', 'active')
# 					break;
# 		case "04" : searchForm.find('li[id=D]').attr('class', 'active')
# 					break;
# 		case "05" : searchForm.find('li[id=E]').attr('class', 'active')
# 					break;
# 		case "06" : searchForm.find('li[id=F]').attr('class', 'active')
# 					break;
# 		case "07" : searchForm.find('li[id=G]').attr('class', 'active')
# 					break;
# 		case "08" : searchForm.find('li[id=H]').attr('class', 'active')
# 					break;
# 		case "09" : searchForm.find('li[id=I]').attr('class', 'active')
# 					break;
# 		case "10" : searchForm.find('li[id=J]').attr('class', 'active')
# 					break;
# 		case "11" : searchForm.find('li[id=K]').attr('class', 'active')
# 					break;
# 		case "12" : searchForm.find('li[id=L]').attr('class', 'active')
# 					break;
# 		case "13" : searchForm.find('li[id=M]').attr('class', 'last active')
# 					break;
# 	}
# }
#
# function fnClassDelete() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('li[id=A]').attr('class', 'first');
# 	searchForm.find('li[id=B]').attr('class', '');
# 	searchForm.find('li[id=C]').attr('class', '');
# 	searchForm.find('li[id=D]').attr('class', '');
# 	searchForm.find('li[id=E]').attr('class', '');
# 	searchForm.find('li[id=F]').attr('class', '');
# 	searchForm.find('li[id=G]').attr('class', '');
# 	searchForm.find('li[id=H]').attr('class', '');
# 	searchForm.find('li[id=I]').attr('class', '');
# 	searchForm.find('li[id=J]').attr('class', '');
# 	searchForm.find('li[id=K]').attr('class', '');
# 	searchForm.find('li[id=L]').attr('class', '');
# 	searchForm.find('li[id=M]').attr('class', 'last');
# }
#
# function fnSearchCallBack(data){
# 	$("#contents").empty().append(data);
# 	var menuNum = $("#searchMenu").val();
# 	// 04:액면변경, 05:주식배당, 06:감자, 09:결산실적공시 예정
# 	if(menuNum == '04' || menuNum == '05' || menuNum == '06' || menuNum =='09') {
# 		$("tr:even").addClass("active");
# 	} else {
# 		$("tr:odd").addClass("active");
# 	}
# 	fnLegendTooltip();
# }
#
# function fnYearChange(){
# 	fnSwapImage($('#searchForm').find('select[name=showMonth]').val(), 'click');
# }
#
# function fnSwapImage(val, type){
# 	var searchForm = $('#searchForm');
# 	var month = "";
# 	if (type == "click"){
# 		document.searchForm.periodType[0].checked = true;
# 		document.searchForm.periodType[1].checked = false;
# 		month = val;
# 	} else {
# 		month = searchForm.find('input:hidden[name=nowMonth]').val();
# 	}
#
# 	searchForm.find('select[name=showMonth]').val(month);
#
# 	clearBtnImage();
#
# 	fnMonthActive(month);
#
# 	//기본으로 오늘날짜 세팅해주기
#  	var vDate, vMon, vDay;
# 	vDate = new Date();
# 	vDate.setDate(vDate.getDate());
#
# 	var curYearMonth = String(vDate.getFullYear())+"-"+String(vMon);
#
# 	if( searchForm.find('select[name=selYear]').val()  ==  String(vDate.getFullYear()) && searchForm.find('select[name=showMonth]').val()  == String(vDate.getMonth()+1)) {
#
# 		//-- <10
# 		if ( (vDate.getMonth()+1) < 10 ) vMon = "0"+String(vDate.getMonth()+1);
# 		else vMon = String(vDate.getMonth()+1);
# 		//-- <10
# 		if ( vDate.getDate() < 10 ) vDay = "0"+String(vDate.getDate());
# 		else vDay =String(vDate.getDate());
#
# 		searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + String(vMon) + "-" + String(vDay));
#
# 	} else {
#
# 		if(val < 10) {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-0" + val + "-01");
# 		} else {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + val + "-01");
# 		}
#
# 	}
#
# 	fnSearchInit($('#searchForm > #searchMenu').val());
# 	fnClassActive($('#searchForm > #searchMenu').val());
# }
#
# function fnMonthActive(month){
# 	var searchForm = $('#searchForm');
# 	switch(month){
# 		case "1" : searchForm.find('a[id=january]').attr('class', 'ord-00 active')
# 					break;
# 		case "2" : searchForm.find('a[id=february]').attr('class', 'ord-01 active')
# 					break;
# 		case "3" : searchForm.find('a[id=march]').attr('class', 'ord-02 active')
# 					break;
# 		case "4" : searchForm.find('a[id=april]').attr('class', 'ord-03 active')
# 					break;
# 		case "5" : searchForm.find('a[id=may]').attr('class', 'ord-04 active')
# 					break;
# 		case "6" : searchForm.find('a[id=june]').attr('class', 'ord-05 active')
# 					break;
# 		case "7" : searchForm.find('a[id=july]').attr('class', 'ord-06 active')
# 					break;
# 		case "8" : searchForm.find('a[id=august]').attr('class', 'ord-07 active')
# 					break;
# 		case "9" : searchForm.find('a[id=september]').attr('class', 'ord-08 active')
# 					break;
# 		case "10" : searchForm.find('a[id=october]').attr('class', 'ord-09 active')
# 					break;
# 		case "11" : searchForm.find('a[id=november]').attr('class', 'ord-10 active')
# 					break;
# 		case "12" : searchForm.find('a[id=december]').attr('class', 'ord-11 active')
# 					break;
# 	}
# }
#
# function clearBtnImage(){
# 	var searchForm = $('#searchForm');
# 	searchForm.find('a[id=january]').attr('class', 'ord-00');
# 	searchForm.find('a[id=february]').attr('class', 'ord-01');
# 	searchForm.find('a[id=march]').attr('class', 'ord-02');
# 	searchForm.find('a[id=april]').attr('class', 'ord-03');
# 	searchForm.find('a[id=may]').attr('class', 'ord-04');
# 	searchForm.find('a[id=june]').attr('class', 'ord-05');
# 	searchForm.find('a[id=july]').attr('class', 'ord-06');
# 	searchForm.find('a[id=august]').attr('class', 'ord-07');
# 	searchForm.find('a[id=september]').attr('class', 'ord-08');
# 	searchForm.find('a[id=october]').attr('class', 'ord-09');
# 	searchForm.find('a[id=november]').attr('class', 'ord-10');
# 	searchForm.find('a[id=december]').attr('class', 'ord-11');
# }
#
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(comAbbrv)
# 	$("#searchForm > #repIsuSrtCd").val(isurCd);
# 	fnSearchCorpName($('#searchForm > #searchMenu').val());
# }
#
# function keyEvent(e){
#   if(document.all){
#     if(window.event.keyCode==13){
#     	fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }else{
#     if(e==13){
# 		fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }
# }
#
# function chkLmtDate() {
# 	var dateVal = $("#searchForm").find("input:text[name=selDate]").val();
# 	if(dateVal.length == 8){
# 		if(dateVal.substring(0,4) < 1999){
# 			alert("1999년부터 조회 가능합니다.");
# 			$("#searchForm").find("input:text[name=selDate]").val("1999-01-01");
# 			return false;
# 		}
# 	}
#
# 	//날짜포멧 공통함수
# 	chkDate('document.searchForm.selDate');
# }
#
# function focusPeriodType() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('input:radio[id=periodType1]').attr('checked', false);
# 	searchForm.find('input:radio[id=periodType2]').attr('checked', true);
# 	$('#searchForm > #enterFlag').val("");
# }
#
# function fnCompanySearch(tabIndex, isurCd){
# 	$('#searchForm > #searchCodeType').val("number");
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(isurCd);
#
# 	//유상증자
#   if(tabIndex == "01"){
# 	fnSearchInit("02");
# 	fnClassActive("02");
#   //무상증자
#   }else if(tabIndex == "02"){
# 	fnSearchInit("03");
# 	fnClassActive("03");
#   //액면변경
#   }else if(tabIndex == "03"){
# 	fnSearchInit("04");
# 	fnClassActive("04");
#   //감자
#   }else if(tabIndex == "04"){
# 	fnSearchInit("06");
# 	fnClassActive("06");
#   //분할/합병
#   }else if(tabIndex == "05" || tabIndex == "11"){
# 	fnSearchInit("07");
# 	fnClassActive("07");
#   //상호변경
#   }else if(tabIndex == "07"){
# 	fnSearchInit("08");
# 	fnClassActive("08");
#   //주주총회
#   }else if(tabIndex == "08"){
# 	fnSearchInit("10");
# 	fnClassActive("10");
#   //불성실공시법인지정
#   }else if(tabIndex == "09"){
# 	fnSearchInit("12");
# 	fnClassActive("12");
#   //수직배당
#   }else if(tabIndex == "12"){
# 	fnSearchInit("05");
# 	fnClassActive("05");
#   //결산실적공시 예정
#   }else if(tabIndex == "13"){
# 	fnSearchInit("09");
# 	fnClassActive("09");
#   //감사보고서 제출 현황
#   }else if(tabIndex == "14"){
# 	fnSearchInit("11");
# 	fnClassActive("11");
#   }
# }
#
# //검색버튼 눌렀을경우 회사명 먼저 조회한다
# function fnSearchCorpName(no){
# 	var	val = $("#searchForm").find("input:text[name=searchCorpName]").val();
# 	if(val == ""){
# 		$("#searchForm > #repIsuSrtCd").val("");
# 	}
# 	if(val != "" && val != ("회사명/코드")){
# 		$('#searchForm > #searchMenu').val(no);
# 		fnAKCKwdSearchCorpName();
# 	}else{
# 		fnSearch(no);
# 	}
# }
#
# function fnSearchCorpNameAllCallBack(items)  {
# 	$("#searchForm > #repIsuSrtCd").val('');
# 	if(items.length == 1) {
# 		$("#searchForm > #repIsuSrtCd").val(items[0].isurcd + "0");
# 		fnSearchCorpCode();
# 		fnSetCookieCrop(items);
# 	} else {
# 		fnSearchCorpCode();
# 	}
# }
#
# //회사명 조회 결과
# function fnSearchCorpCode(){
# 	var repIsuSrtCd = $("#searchForm > #repIsuSrtCd").val();
#
# 	if(repIsuSrtCd == ""){
# 		alert("조회한 회사명이 존재하지 않습니다. \n정확한 회사명을 입력해 주세요. \n회사명이 정확하지 않으시면 회사명 검색을 이용해주세요.");
# 		$("#searchCorpName").val("");
# 	}
# 	fnSearch($('#searchForm > #searchMenu').val());
# }
#
# function fnTextInit() {
# 	if($("#searchCorpName").val() == "회사명/코드") {
# 		$("#searchCorpName").val("");
# 	}
# }
#   </script>
#   <footer class="popup">
#    <div class="btn-group type-98">
#     <a class="btn-sprite type-98 vmiddle" href="#myclose" onclick="fnPopClose(); return false;" title="닫기">
#      <span>
#       닫 기
#      </span>
#     </a>
#    </div>
#   </footer>
#   <!-- 범례 START -->
#   <div id="marketSection" style="position:absolute; display:none">
#    <section class="icn_tbox" style="width:400px;top:-30px; left:10px">
#     <ul>
#      <li>
#       <img alt="유가증권" class="vmiddle" src="../images/common/icn_t_yu.gif"/>
#       유가증권
#      </li>
#      <li>
#       <img alt="코스닥" class="vmiddle" src="../images/common/icn_t_ko.gif"/>
#       코스닥
#      </li>
#      <li>
#       <img alt="코넥스" class="vmiddle" src="../images/common/icn_t_konex.gif"/>
#       코넥스
#      </li>
#      <li>
#       <img alt="관리종목" class="vmiddle" src="../images/common/icn_t_kwan.gif"/>
#       관리종목
#      </li>
#      <li>
#       <img alt="투자주의환기종목" class="vmiddle" src="../images/common/icn_t_hwan.gif"/>
#       투자주의환기종목
#      </li>
#      <li>
#       <img alt="불성실공시법인" class="vmiddle" src="../images/common/icn_t_bul.gif"/>
#       불성실공시법인
#      </li>
#      <li>
#       <img alt="폐지법인" class="vmiddle" src="../images/common/icn_t_pe.gif"/>
#       폐지법인
#      </li>
#      <li>
#       <img alt="KTOP30" class="vmiddle" src="../images/common/icn_t_ktop.gif"/>
#       KTOP30
#      </li>
#      <li>
#       <img alt="KOSPI200" class="vmiddle" src="../images/common/icn_t_k200.gif"/>
#       KOSPI200
#      </li>
#      <li>
#       <img alt="KOSDAQ150" class="vmiddle" src="../images/common/icn_t_q150.gif"/>
#       KOSDAQ150
#      </li>
#      <li>
#       <img alt="KRX300" class="vmiddle" src="../images/common/icn_t_x300.gif"/>
#       KRX300
#      </li>
#      <li>
#       <img alt="정정있음" class="vmiddle" src="../images/common/icn_t_jung.gif"/>
#       정정있음
#      </li>
#      <li>
#       <img alt="투자주의" class="vmiddle" src="../images/common/icn_t_joo.gif"/>
#       투자주의
#      </li>
#      <li>
#       <img alt="투자경고" class="vmiddle" src="../images/common/icn_t_kyung.gif"/>
#       투자경고
#      </li>
#      <li>
#       <img alt="투자위험" class="vmiddle" src="../images/common/icn_t_wii.gif"/>
#       투자위험
#      </li>
#     </ul>
#     <div class="clear">
#     </div>
#     <img alt="" class="tl" src="../images/common/icn_tbox_tl.png"/>
#     <img alt="" class="bl" src="../images/common/icn_tbox_bl.gif"/>
#     <img alt="" class="tr" src="../images/common/icn_tbox_tr.gif"/>
#     <img alt="" class="br" src="../images/common/icn_tbox_br.gif"/>
#     <div class="tm">
#     </div>
#     <div class="lm">
#     </div>
#     <div class="bm">
#     </div>
#     <div class="rm">
#     </div>
#    </section>
#   </div>
#   <!-- 범례 END -->
#   <div class="loading" id="dialog-loading" style="display: none;" title="자료를 조회 중입니다.">
#    <span>
#     <img src="/images/loader/ajax-loader01.gif"/>
#    </span>
#   </div>
#  </body>
# </html>
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="kr" http-equiv="content-language"/>
#   <meta content="text/css" http-equiv="content-style-type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="no" http-equiv="imagetoolbar"/>
#   <meta content="(c)2012" name="copyright"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="description"/>
#   <meta content="대한민국 대표 기업공시채널 KIND" name="keywords"/>
#   <title>
#    대한민국 대표 기업공시채널 KIND
#   </title>
#   <link href="../js/jquery/themes-base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/default_new.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/common.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="../css/popup.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
#   <script src="../js/trans.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <script src="../js/jquery/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="../js/common.js" type="text/javascript">
#   </script>
#   <script src="../js/common-pop.js?version=20220624" type="text/javascript">
#   </script>
#   <script src="../js/common-ajax.js" type="text/javascript">
#   </script>
#   <script src="../js/JCommon.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="pop">
#   <header class="popup">
#    <h1 class="ttl type-99" id="title">
#     증시일정
#    </h1>
#   </header>
#   <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
#    <input id="method" name="method" type="hidden"/>
#    <input id="forward" name="forward" type="hidden"/>
#    <input id="searchCodeType" name="searchCodeType" type="hidden"/>
#    <!--number:법인코드 char:법인명-->
#    <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden"/>
#    <!--법인코드-->
#    <input id="menuIndex" name="menuIndex" type="hidden"/>
#    <!--검색할 페이지-->
#    <input id="selMonth" name="selMonth" type="hidden"/>
#    <!--월-->
#    <input id="selDay" name="selDay" type="hidden"/>
#    <!--일자-->
#    <input id="enterFlag" name="enterFlag" type="hidden"/>
#    <input id="searchMenu" name="searchMenu" type="hidden" value="01"/>
#    <input id="nowYear" name="nowYear" type="hidden" value="2023"/>
#    <input id="nowMonth" name="nowMonth" type="hidden" value="11"/>
#    <!-- 리스트검색 -->
#    <section class="contents popup">
#     <section class="roundbox type-99">
#      <div class="form-search type-99">
#       <table summary="검색">
#        <caption>
#         증시일정
#        </caption>
#        <colgroup>
#         <col width="50"/>
#         <col width="200"/>
#         <col width="90"/>
#         <col width="*"/>
#        </colgroup>
#        <tbody>
#         <tr class="first">
#          <th scope="row">
#           <label for="name">
#            회사명
#           </label>
#          </th>
#          <td>
#           <input class="middle" id="searchCorpName" name="searchCorpName" onclick="fnTextInit(); return false;" type="text"/>
#           <a href="#searchCorp" onclick="findCompanyName();return false;" title="회사명찾기">
#            <img alt="회사명찾기" class="vtop" id="searchCorp" src="../../images/common/btn_zoom.gif"/>
#           </a>
#          </td>
#          <td>
#           <select class="select" id="selYear" name="selYear" onchange="fnYearChange()">
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option selected="selected" value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#            <option value="2025">
#             2025
#            </option>
#           </select>
#           년
#           <select class="select" id="showMonth" name="showMonth" style="display:none">
#            <option value="1">
#             1
#            </option>
#            <option value="2">
#             2
#            </option>
#            <option value="3">
#             3
#            </option>
#            <option value="4">
#             4
#            </option>
#            <option value="5">
#             5
#            </option>
#            <option value="6">
#             6
#            </option>
#            <option value="7">
#             7
#            </option>
#            <option value="8">
#             8
#            </option>
#            <option value="9">
#             9
#            </option>
#            <option value="10">
#             10
#            </option>
#            <option selected="selected" value="11">
#             11
#            </option>
#            <option value="12">
#             12
#            </option>
#           </select>
#          </td>
#          <td>
#           <ul class="btn-set months">
#            <li>
#             <a class="ord-00" href="#" id="january" onclick="fnSwapImage('1', 'click')" title="1월">
#              <span>
#               1월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-01" href="#" id="february" onclick="fnSwapImage('2', 'click')" title="2월">
#              <span>
#               2월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-02" href="#" id="march" onclick="fnSwapImage('3', 'click')" title="3월">
#              <span>
#               3월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-03" href="#" id="april" onclick="fnSwapImage('4', 'click')" title="4월">
#              <span>
#               4월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-04" href="#" id="may" onclick="fnSwapImage('5', 'click')" title="5월">
#              <span>
#               5월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-05" href="#" id="june" onclick="fnSwapImage('6', 'click')" title="6월">
#              <span>
#               6월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-06" href="#" id="july" onclick="fnSwapImage('7', 'click')" title="7월">
#              <span>
#               7월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-07" href="#" id="august" onclick="fnSwapImage('8', 'click')" title="8월">
#              <span>
#               8월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-08" href="#" id="september" onclick="fnSwapImage('9', 'click')" title="9월">
#              <span>
#               9월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-09" href="#" id="october" onclick="fnSwapImage('10', 'click')" title="10월">
#              <span>
#               10월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-10" href="#" id="november" onclick="fnSwapImage('11', 'click')" title="11월">
#              <span>
#               11월
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="ord-11" href="#" id="december" onclick="fnSwapImage('12', 'click')" title="12월">
#              <span>
#               12월
#              </span>
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#      <img alt="" class="tl" src="../images/common/rbox-type-99-tl.png"/>
#      <img alt="" class="bl" src="../images/common/rbox-type-99-bl.png"/>
#      <img alt="" class="tr" src="../images/common/rbox-type-99-tr.png"/>
#      <img alt="" class="br" src="../images/common/rbox-type-99-br.png"/>
#      <div class="tm">
#      </div>
#      <div class="lm">
#      </div>
#      <div class="bm">
#      </div>
#      <div class="rm">
#      </div>
#     </section>
#     <nav class="tabgroup type-97 mt10">
#      <ul>
#       <li id="A">
#        <a href="#" onclick="fnSearchInit('01'); fnClassActive('01'); return false;" title="종합">
#         <span>
#          종합
#         </span>
#        </a>
#       </li>
#       <li id="B">
#        |
#        <a href="#" onclick="fnSearchInit('02'); fnClassActive('02'); return false;" title="유상종자">
#         <span>
#          유상증자
#         </span>
#        </a>
#       </li>
#       <li id="C">
#        |
#        <a href="#" onclick="fnSearchInit('03'); fnClassActive('03'); return false;" title="무상종자">
#         <span>
#          무상증자
#         </span>
#        </a>
#       </li>
#       <li id="D">
#        |
#        <a href="#" onclick="fnSearchInit('04'); fnClassActive('04'); return false;" title="액면변경">
#         <span>
#          액면변경
#         </span>
#        </a>
#       </li>
#       <li id="E">
#        |
#        <a href="#" onclick="fnSearchInit('05'); fnClassActive('05'); return false;" title="주식배당">
#         <span>
#          주식배당
#         </span>
#        </a>
#       </li>
#       <li id="F">
#        |
#        <a href="#" onclick="fnSearchInit('06'); fnClassActive('06'); return false;" title="감자">
#         <span>
#          감자
#         </span>
#        </a>
#       </li>
#       <li id="G">
#        |
#        <a href="#" onclick="fnSearchInit('07'); fnClassActive('07'); return false;" title="분할/합병">
#         <span>
#          분할/합병
#         </span>
#        </a>
#       </li>
#       <li id="H">
#        |
#        <a href="#" onclick="fnSearchInit('08'); fnClassActive('08'); return false;" title="상호변경">
#         <span>
#          상호변경
#         </span>
#        </a>
#       </li>
#       <li id="I">
#        |
#        <a href="#" onclick="fnSearchInit('09'); fnClassActive('09'); return false;" title="결산실적공시 예정">
#         <span>
#          결산실적공시 예정
#         </span>
#        </a>
#       </li>
#       <li id="J">
#        |
#        <a href="#" onclick="fnSearchInit('10'); fnClassActive('10'); return false;" title="주주총회">
#         <span>
#          주주총회
#         </span>
#        </a>
#       </li>
#       <li id="K">
#        |
#        <a href="#" onclick="fnSearchInit('11'); fnClassActive('11'); return false;" title="감사보고서 제출 현황">
#         <span>
#          감사보고서 제출 현황
#         </span>
#        </a>
#       </li>
#       <li id="L">
#        |
#        <a href="#" onclick="fnSearchInit('12'); fnClassActive('12'); return false;" title="불성실공시법인지정">
#         <span>
#          불성실공시법인지정
#         </span>
#        </a>
#       </li>
#       <li id="M">
#        |
#        <a href="#" onclick="fnSearchInit('13'); fnClassActive('13'); return false;" title="트레이딩캘린더">
#         <span>
#          트레이딩캘린더
#         </span>
#        </a>
#       </li>
#      </ul>
#      <div class="clear">
#      </div>
#     </nav>
#     <div id="search" style="display:none">
#      <section class="roundbox type-99">
#       <div class="form-search type-99">
#        <table summary="기간,시장구분,제출구분">
#         <caption>
#          감사보고서 제출 현황 검색
#         </caption>
#         <colgroup>
#          <col width="70"/>
#          <col width="*"/>
#          <col width="70"/>
#          <col width="*"/>
#         </colgroup>
#         <tbody>
#          <tr class="first">
#           <th scope="row">
#            <label for="selDate">
#             기간
#            </label>
#           </th>
#           <td colspan="3">
#            <input checked="checked" class="rad-00" id="periodType1" name="periodType" type="radio" value="M"/>
#            <label for="periodType1">
#             월간
#            </label>
#            <input class="rad-00" id="periodType2" name="periodType" type="radio" value="D"/>
#            <label for="periodType2">
#             일간
#            </label>
#            <input class="txt input-calendar" id="selDate" name="selDate" onfocus="cal_offMask('document.searchForm.selDate'); focusPeriodType(); return false;" onkeyup="chkLmtDate();return false;" title="기간선택 첫번째" type="text" value=""/>
#           </td>
#          </tr>
#          <tr>
#           <th scope="row">
#            <label for="ldMktTpCd1" id="marketType_div">
#             시장구분
#            </label>
#           </th>
#           <td>
#            <input checked="checked" class="rad-00" id="ldMktTpCd1" name="ldMktTpCd" type="radio" value=""/>
#            <label for="ldMktTpCd1">
#             전체
#            </label>
#            <input class="rad-00" id="ldMktTpCd2" name="ldMktTpCd" type="radio" value="1"/>
#            <label for="ldMktTpCd2">
#             유가증권
#            </label>
#            <input class="rad-00" id="ldMktTpCd3" name="ldMktTpCd" type="radio" value="2"/>
#            <label for="ldMktTpCd3">
#             코스닥
#            </label>
#            <input class="rad-00" id="ldMktTpCd4" name="ldMktTpCd" type="radio" value="6"/>
#            <label for="ldMktTpCd3">
#             코넥스
#            </label>
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("02" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('02');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# ...
#           </td>
#           <th scope="row">
#            <label for="submitFlagYn1" id="sumitType_div">
#             제출구분
#            </label>
#           </th>
#           <td>
#            <input class="rad-00" id="submitFlagYn1" name="submitFlagYn" type="radio" value=""/>
#            <label for="submitFlagYn1">
#             전체
#            </label>
#            <input class="rad-00" id="submitFlagYn2" name="submitFlagYn" type="radio" value="Y"/>
#            <label for="submitFlagYn2">
#             제출
#            </label>
#            <input checked="checked" class="rad-00" id="submitFlagYn3" name="submitFlagYn" type="radio" value="N"/>
#            <label for="submitFlagYn3">
#             미제출
#            </label>
#            <input class="rad-00" id="submitFlagYn4" name="submitFlagYn" type="radio" value="A"/>
#            <label for="submitFlagYn4">
#             제출기한 미도래
#            </label>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="btn-group rt">
#         <a class="btn-set search-btn" href="#" onclick="fnSearchInit('11'); return false;" title="검색">
#          <span>
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div id="contents">
#     </div>
#    </section>
#   </form>
#   <script type="text/JavaScript">
#    $(document).ready(function(){
# 	init();
# });
#
# function init(){
# 	var searchForm = $('#searchForm');
#
# 	if("2023" != ""){
# 		searchForm.find('select[name=selYear]').val('2023');
# 	}
#
# 	if("12" != ""){
# 		searchForm.find('input:hidden[name=nowMonth]').val('12');
# 	}
#
# 	if("" != ""){
# 		$("#searchCorpName").val("");
# 	} else {
# 		$("#searchCorpName").val("회사명/코드");
# 	}
#
# 	var p_idx = '11';
# 	if(p_idx != ""){
# 		if(p_idx < 10){
# 			$('#searchForm > #searchMenu').val("0"+p_idx);
# 		}else{
# 			$('#searchForm > #searchMenu').val(p_idx);
# 		}
# 	} else {
# 		$('#searchForm > #searchMenu').val("01");
# 	}
#
# 	fnSwapImage($('#searchForm > #nowMonth').val(), '');
# }
#
# function fnSearchInit(no){
# 	$("#searchForm > #pageIndex").val("1");
# 	fnSearchCorpName(no);
# }
#
# function fnSearch(no){
# 	var searchForm = $('#searchForm');
# 	if(searchForm.find('select[name=showMonth]').val() < 10){
# 		searchForm.find('input:hidden[name=selMonth]').val("0" + searchForm.find('select[name=showMonth]').val());
# 	}else{
# 		searchForm.find('input:hidden[name=selMonth]').val(searchForm.find('select[name=showMonth]').val());
# 	}
# 	var method	= "searchTotalCalendar";
# 	var forward = "searchtotalcalendar";
#
# 	if (no == "11")	{
# 		$(document).find('div[id=search]').css("display", "block");
# 	} else {
# 		$(document).find('div[id=search]').css("display", "none");
# 	}
#
# 	switch(no){
# 		case "01" : method = "searchTotalCalendar"; forward ="searchtotalcalendar";								//종합
# 					break;
# 		case "02" : method = "searchPaidinCapitalIncrease"; forward ="searchpaidincapitalincrease";				//유상증자
# 					break;
# 		case "03" : method = "searchFreeIssueNewShares"; forward ="searchfreeissuenewshares";					//무상증자
# 					break;
# 		case "04" : method = "searchFaceValueChange"; forward ="searchfacevaluechange";							//액면변경
# 					break;
# 		case "05" : method = "searchStockDividend"; forward ="searchstockdividend";								//주식배당
# 					break;
# 		case "06" : method = "searchReductionCapital"; forward ="searchreductioncapital";						//감자
# 					break;
# 		case "07" : method = "searchDivisionAffiliation"; forward ="searchdivisionaffiliation";					//분할&합병
# 					break;
# 		case "08" : method = "searchNameChange"; forward ="searchnamechange";									//상호변경
# 					break;
# 		case "09" : method = "searchBalancingAccountsResultSch"; forward ="searchbalancingaccountsresultsch";	//결산실적공시 예정
# 					break;
# 		case "10" : method = "searchGeneralMeetingStockholders"; forward ="searchgeneralmeetingstockholders";	//주주총회
# 					break;
# 		case "11" : method = "searchAuditReportReleaseState"; forward ="searchauditreportreleasestate";			//감사보고서 제출 현황
# 					break;
# 		case "12" : method = "searchInsincerityDistribute"; forward ="searchinsinceritydistribute";				//불성실공시법인지정
# 					break;
# 		case "13" : method = "searchTraidingCalendar"; forward ="searchtraidingcalendar";						//트레이딩캘린더
# 					break;
# 	}
#
# 	$('#searchForm > #searchMenu').val(no);
# 	$("#searchForm > #method").val(method);
# 	$("#searchForm > #forward").val(forward);
#
# 	searchForm.ajaxSubmit({
# 		  ajaxUrl : '/common/stockschedule.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnClassActive(no) {
# 	var searchForm = $('#searchForm');
# 	fnClassDelete();
# 	switch(no){
# 		case "01" : searchForm.find('li[id=A]').attr('class', 'first active')
# 					break;
# 		case "02" : searchForm.find('li[id=B]').attr('class', 'active')
# 					break;
# 		case "03" : searchForm.find('li[id=C]').attr('class', 'active')
# 					break;
# 		case "04" : searchForm.find('li[id=D]').attr('class', 'active')
# 					break;
# 		case "05" : searchForm.find('li[id=E]').attr('class', 'active')
# 					break;
# 		case "06" : searchForm.find('li[id=F]').attr('class', 'active')
# 					break;
# 		case "07" : searchForm.find('li[id=G]').attr('class', 'active')
# 					break;
# 		case "08" : searchForm.find('li[id=H]').attr('class', 'active')
# 					break;
# 		case "09" : searchForm.find('li[id=I]').attr('class', 'active')
# 					break;
# 		case "10" : searchForm.find('li[id=J]').attr('class', 'active')
# 					break;
# 		case "11" : searchForm.find('li[id=K]').attr('class', 'active')
# 					break;
# 		case "12" : searchForm.find('li[id=L]').attr('class', 'active')
# 					break;
# 		case "13" : searchForm.find('li[id=M]').attr('class', 'last active')
# 					break;
# 	}
# }
#
# function fnClassDelete() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('li[id=A]').attr('class', 'first');
# 	searchForm.find('li[id=B]').attr('class', '');
# 	searchForm.find('li[id=C]').attr('class', '');
# 	searchForm.find('li[id=D]').attr('class', '');
# 	searchForm.find('li[id=E]').attr('class', '');
# 	searchForm.find('li[id=F]').attr('class', '');
# 	searchForm.find('li[id=G]').attr('class', '');
# 	searchForm.find('li[id=H]').attr('class', '');
# 	searchForm.find('li[id=I]').attr('class', '');
# 	searchForm.find('li[id=J]').attr('class', '');
# 	searchForm.find('li[id=K]').attr('class', '');
# 	searchForm.find('li[id=L]').attr('class', '');
# 	searchForm.find('li[id=M]').attr('class', 'last');
# }
#
# function fnSearchCallBack(data){
# 	$("#contents").empty().append(data);
# 	var menuNum = $("#searchMenu").val();
# 	// 04:액면변경, 05:주식배당, 06:감자, 09:결산실적공시 예정
# 	if(menuNum == '04' || menuNum == '05' || menuNum == '06' || menuNum =='09') {
# 		$("tr:even").addClass("active");
# 	} else {
# 		$("tr:odd").addClass("active");
# 	}
# 	fnLegendTooltip();
# }
#
# function fnYearChange(){
# 	fnSwapImage($('#searchForm').find('select[name=showMonth]').val(), 'click');
# }
#
# function fnSwapImage(val, type){
# 	var searchForm = $('#searchForm');
# 	var month = "";
# 	if (type == "click"){
# 		document.searchForm.periodType[0].checked = true;
# 		document.searchForm.periodType[1].checked = false;
# 		month = val;
# 	} else {
# 		month = searchForm.find('input:hidden[name=nowMonth]').val();
# 	}
#
# 	searchForm.find('select[name=showMonth]').val(month);
#
# 	clearBtnImage();
#
# 	fnMonthActive(month);
#
# 	//기본으로 오늘날짜 세팅해주기
#  	var vDate, vMon, vDay;
# 	vDate = new Date();
# 	vDate.setDate(vDate.getDate());
#
# 	var curYearMonth = String(vDate.getFullYear())+"-"+String(vMon);
#
# 	if( searchForm.find('select[name=selYear]').val()  ==  String(vDate.getFullYear()) && searchForm.find('select[name=showMonth]').val()  == String(vDate.getMonth()+1)) {
#
# 		//-- <10
# 		if ( (vDate.getMonth()+1) < 10 ) vMon = "0"+String(vDate.getMonth()+1);
# 		else vMon = String(vDate.getMonth()+1);
# 		//-- <10
# 		if ( vDate.getDate() < 10 ) vDay = "0"+String(vDate.getDate());
# 		else vDay =String(vDate.getDate());
#
# 		searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + String(vMon) + "-" + String(vDay));
#
# 	} else {
#
# 		if(val < 10) {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-0" + val + "-01");
# 		} else {
# 			searchForm.find('input:text[name=selDate]').val(searchForm.find('select[name=selYear]').val() + "-" + val + "-01");
# 		}
#
# 	}
#
# 	fnSearchInit($('#searchForm > #searchMenu').val());
# 	fnClassActive($('#searchForm > #searchMenu').val());
# }
#
# function fnMonthActive(month){
# 	var searchForm = $('#searchForm');
# 	switch(month){
# 		case "1" : searchForm.find('a[id=january]').attr('class', 'ord-00 active')
# 					break;
# 		case "2" : searchForm.find('a[id=february]').attr('class', 'ord-01 active')
# 					break;
# 		case "3" : searchForm.find('a[id=march]').attr('class', 'ord-02 active')
# 					break;
# 		case "4" : searchForm.find('a[id=april]').attr('class', 'ord-03 active')
# 					break;
# 		case "5" : searchForm.find('a[id=may]').attr('class', 'ord-04 active')
# 					break;
# 		case "6" : searchForm.find('a[id=june]').attr('class', 'ord-05 active')
# 					break;
# 		case "7" : searchForm.find('a[id=july]').attr('class', 'ord-06 active')
# 					break;
# 		case "8" : searchForm.find('a[id=august]').attr('class', 'ord-07 active')
# 					break;
# 		case "9" : searchForm.find('a[id=september]').attr('class', 'ord-08 active')
# 					break;
# 		case "10" : searchForm.find('a[id=october]').attr('class', 'ord-09 active')
# 					break;
# 		case "11" : searchForm.find('a[id=november]').attr('class', 'ord-10 active')
# 					break;
# 		case "12" : searchForm.find('a[id=december]').attr('class', 'ord-11 active')
# 					break;
# 	}
# }
#
# function clearBtnImage(){
# 	var searchForm = $('#searchForm');
# 	searchForm.find('a[id=january]').attr('class', 'ord-00');
# 	searchForm.find('a[id=february]').attr('class', 'ord-01');
# 	searchForm.find('a[id=march]').attr('class', 'ord-02');
# 	searchForm.find('a[id=april]').attr('class', 'ord-03');
# 	searchForm.find('a[id=may]').attr('class', 'ord-04');
# 	searchForm.find('a[id=june]').attr('class', 'ord-05');
# 	searchForm.find('a[id=july]').attr('class', 'ord-06');
# 	searchForm.find('a[id=august]').attr('class', 'ord-07');
# 	searchForm.find('a[id=september]').attr('class', 'ord-08');
# 	searchForm.find('a[id=october]').attr('class', 'ord-09');
# 	searchForm.find('a[id=november]').attr('class', 'ord-10');
# 	searchForm.find('a[id=december]').attr('class', 'ord-11');
# }
#
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(comAbbrv)
# 	$("#searchForm > #repIsuSrtCd").val(isurCd);
# 	fnSearchCorpName($('#searchForm > #searchMenu').val());
# }
#
# function keyEvent(e){
#   if(document.all){
#     if(window.event.keyCode==13){
#     	fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }else{
#     if(e==13){
# 		fnSearchInit($('#searchForm > #searchMenu').val());
#     }
#   }
# }
#
# function chkLmtDate() {
# 	var dateVal = $("#searchForm").find("input:text[name=selDate]").val();
# 	if(dateVal.length == 8){
# 		if(dateVal.substring(0,4) < 1999){
# 			alert("1999년부터 조회 가능합니다.");
# 			$("#searchForm").find("input:text[name=selDate]").val("1999-01-01");
# 			return false;
# 		}
# 	}
#
# 	//날짜포멧 공통함수
# 	chkDate('document.searchForm.selDate');
# }
#
# function focusPeriodType() {
# 	var searchForm = $('#searchForm');
# 	searchForm.find('input:radio[id=periodType1]').attr('checked', false);
# 	searchForm.find('input:radio[id=periodType2]').attr('checked', true);
# 	$('#searchForm > #enterFlag').val("");
# }
#
# function fnCompanySearch(tabIndex, isurCd){
# 	$('#searchForm > #searchCodeType').val("number");
# 	$('#searchForm').find('input:text[name=searchCorpName]').val(isurCd);
#
# 	//유상증자
#   if(tabIndex == "01"){
# 	fnSearchInit("02");
# 	fnClassActive("02");
#   //무상증자
#   }else if(tabIndex == "02"){
# 	fnSearchInit("03");
# 	fnClassActive("03");
#   //액면변경
#   }else if(tabIndex == "03"){
# 	fnSearchInit("04");
# 	fnClassActive("04");
#   //감자
#   }else if(tabIndex == "04"){
# 	fnSearchInit("06");
# 	fnClassActive("06");
#   //분할/합병
#   }else if(tabIndex == "05" || tabIndex == "11"){
# 	fnSearchInit("07");
# 	fnClassActive("07");
#   //상호변경
#   }else if(tabIndex == "07"){
# 	fnSearchInit("08");
# 	fnClassActive("08");
#   //주주총회
#   }else if(tabIndex == "08"){
# 	fnSearchInit("10");
# 	fnClassActive("10");
#   //불성실공시법인지정
#   }else if(tabIndex == "09"){
# 	fnSearchInit("12");
# 	fnClassActive("12");
#   //수직배당
#   }else if(tabIndex == "12"){
# 	fnSearchInit("05");
# 	fnClassActive("05");
#   //결산실적공시 예정
#   }else if(tabIndex == "13"){
# 	fnSearchInit("09");
# 	fnClassActive("09");
#   //감사보고서 제출 현황
#   }else if(tabIndex == "14"){
# 	fnSearchInit("11");
# 	fnClassActive("11");
#   }
# }
#
# //검색버튼 눌렀을경우 회사명 먼저 조회한다
# function fnSearchCorpName(no){
# 	var	val = $("#searchForm").find("input:text[name=searchCorpName]").val();
# 	if(val == ""){
# 		$("#searchForm > #repIsuSrtCd").val("");
# 	}
# 	if(val != "" && val != ("회사명/코드")){
# 		$('#searchForm > #searchMenu').val(no);
# 		fnAKCKwdSearchCorpName();
# 	}else{
# 		fnSearch(no);
# 	}
# }
#
# function fnSearchCorpNameAllCallBack(items)  {
# 	$("#searchForm > #repIsuSrtCd").val('');
# 	if(items.length == 1) {
# 		$("#searchForm > #repIsuSrtCd").val(items[0].isurcd + "0");
# 		fnSearchCorpCode();
# 		fnSetCookieCrop(items);
# 	} else {
# 		fnSearchCorpCode();
# 	}
# }
#
# //회사명 조회 결과
# function fnSearchCorpCode(){
# 	var repIsuSrtCd = $("#searchForm > #repIsuSrtCd").val();
#
# 	if(repIsuSrtCd == ""){
# 		alert("조회한 회사명이 존재하지 않습니다. \n정확한 회사명을 입력해 주세요. \n회사명이 정확하지 않으시면 회사명 검색을 이용해주세요.");
# 		$("#searchCorpName").val("");
# 	}
# 	fnSearch($('#searchForm > #searchMenu').val());
# }
#
# function fnTextInit() {
# 	if($("#searchCorpName").val() == "회사명/코드") {
# 		$("#searchCorpName").val("");
# 	}
# }
#   </script>
#   <footer class="popup">
#    <div class="btn-group type-98">
#     <a class="btn-sprite type-98 vmiddle" href="#myclose" onclick="fnPopClose(); return false;" title="닫기">
#      <span>
#       닫 기
#      </span>
#     </a>
#    </div>
#   </footer>
#   <!-- 범례 START -->
#   <div id="marketSection" style="position:absolute; display:none">
#    <section class="icn_tbox" style="width:400px;top:-30px; left:10px">
#     <ul>
#      <li>
#       <img alt="유가증권" class="vmiddle" src="../images/common/icn_t_yu.gif"/>
#       유가증권
#      </li>
#      <li>
#       <img alt="코스닥" class="vmiddle" src="../images/common/icn_t_ko.gif"/>
#       코스닥
#      </li>
#      <li>
#       <img alt="코넥스" class="vmiddle" src="../images/common/icn_t_konex.gif"/>
#       코넥스
#      </li>
#      <li>
#       <img alt="관리종목" class="vmiddle" src="../images/common/icn_t_kwan.gif"/>
#       관리종목
#      </li>
#      <li>
#       <img alt="투자주의환기종목" class="vmiddle" src="../images/common/icn_t_hwan.gif"/>
#       투자주의환기종목
#      </li>
#      <li>
#       <img alt="불성실공시법인" class="vmiddle" src="../images/common/icn_t_bul.gif"/>
#       불성실공시법인
#      </li>
#      <li>
#       <img alt="폐지법인" class="vmiddle" src="../images/common/icn_t_pe.gif"/>
#       폐지법인
#      </li>
#      <li>
#       <img alt="KTOP30" class="vmiddle" src="../images/common/icn_t_ktop.gif"/>
#       KTOP30
#      </li>
#      <li>
#       <img alt="KOSPI200" class="vmiddle" src="../images/common/icn_t_k200.gif"/>
#       KOSPI200
#      </li>
#      <li>
#       <img alt="KOSDAQ150" class="vmiddle" src="../images/common/icn_t_q150.gif"/>
#       KOSDAQ150
#      </li>
#      <li>
#       <img alt="KRX300" class="vmiddle" src="../images/common/icn_t_x300.gif"/>
#       KRX300
#      </li>
#      <li>
#       <img alt="정정있음" class="vmiddle" src="../images/common/icn_t_jung.gif"/>
#       정정있음
#      </li>
#      <li>
#       <img alt="투자주의" class="vmiddle" src="../images/common/icn_t_joo.gif"/>
#       투자주의
#      </li>
#      <li>
#       <img alt="투자경고" class="vmiddle" src="../images/common/icn_t_kyung.gif"/>
#       투자경고
#      </li>
#      <li>
#       <img alt="투자위험" class="vmiddle" src="../images/common/icn_t_wii.gif"/>
#       투자위험
#      </li>
#     </ul>
#     <div class="clear">
#     </div>
#     <img alt="" class="tl" src="../images/common/icn_tbox_tl.png"/>
#     <img alt="" class="bl" src="../images/common/icn_tbox_bl.gif"/>
#     <img alt="" class="tr" src="../images/common/icn_tbox_tr.gif"/>
#     <img alt="" class="br" src="../images/common/icn_tbox_br.gif"/>
#     <div class="tm">
#     </div>
#     <div class="lm">
#     </div>
#     <div class="bm">
#     </div>
#     <div class="rm">
#     </div>
#    </section>
#   </div>
#   <!-- 범례 END -->
#   <div class="loading" id="dialog-loading" style="display: none;" title="자료를 조회 중입니다.">
#    <span>
#     <img src="/images/loader/ajax-loader01.gif"/>
#    </span>
#   </div>
#  </body>
# </html>

# %%
html_unicode = html.prettify()
tbl = pd.read_html(html.prettify())

tbl[0].head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10380\1205700952.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tbl = pd.read_html(html.prettify())
#      0   1                                                  2  \
# 0  회사명 NaN  1999  2000  2001  2002  2003  2004  2005  2006...
#
#                                                    3
# 0  1월  2월  3월  4월  5월  6월  7월  8월  9월  10월  11월  12월
